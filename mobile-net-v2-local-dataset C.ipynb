# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2  # Changed to MobileNetV2
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, confusion_matrix, 
                           precision_score, recall_score, f1_score, 
                           accuracy_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc
import math
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
from collections import Counter

# ====== CONFIGURATION ======
class Config:
    BATCH_SIZE = 8
    IMG_SIZE = (224, 224)  # MobileNetV2 typically uses 224x224
    NUM_FOLDS = 5
    EPOCHS = 50
    LEARNING_RATE = 3e-5
    DROPOUT_RATE = 0.5
    SE_RATIO = 16
    BASE_DIR = '/kaggle/input/local-preprocessed-dataset/LOCAL PREPROCESSED DATASET'
    SEED = 42
    MIN_SAMPLES = 20

# ====== DATA AUGMENTATION ======
def create_augmenter():
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.95, 1.05],
        fill_mode='reflect',
        validation_split=0.2
    )

# ====== SQUEEZE-EXCITATION BLOCK ======
def se_block(input_tensor, ratio=Config.SE_RATIO):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(channels // ratio, activation='relu', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    
    return layers.Multiply()([input_tensor, se])

# ====== ENHANCED MOBILENETV2 MODEL ======
def build_enhanced_mobilenet(num_classes):
    base_model = MobileNetV2(
        weights='imagenet',
        include_top=False,
        input_shape=(*Config.IMG_SIZE, 3)
    )
    
    # Freeze all convolutional layers
    for layer in base_model.layers:
        layer.trainable = False
    
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    x = layers.Dense(256, activation='relu', 
                    kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=outputs)
    
    optimizer = optimizers.Adam(
        learning_rate=Config.LEARNING_RATE,
        clipnorm=1.0
    )
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')]
    )
    
    return model

# ====== CUSTOM DATA GENERATOR ======
class AdvancedDataGenerator(Sequence):
    def __init__(self, filepaths, labels, datagen, batch_size=32, img_size=(224,224), shuffle=True):
        self.filepaths = filepaths
        self.labels = labels
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.filepaths) / self.batch_size)

    def __getitem__(self, index):
        batch_files = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        images = []
        for filepath in batch_files:
            img = image.load_img(filepath, target_size=self.img_size)
            img_array = image.img_to_array(img)
            img_array = self.datagen.standardize(img_array)
            images.append(img_array)
            
        return np.array(images), tf.keras.utils.to_categorical(batch_labels, num_classes=len(set(self.labels)))

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.filepaths))
            np.random.shuffle(indices)
            self.filepaths = [self.filepaths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# ====== TRAINING PIPELINE ======
def run_training():
    # Initialize data
    datagen = create_augmenter()
    train_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=Config.SEED
    )
    
    # Data integrity checks
    print("\n=== DATA VALIDATION ===")
    print("Class distribution in training:", Counter(train_gen.labels))
    
    val_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=Config.SEED
    )
    print("Class distribution in validation:", Counter(val_gen.labels))
    
    # Verify no overlap
    train_files = set(train_gen.filepaths)
    val_files = set(val_gen.filepaths)
    print(f"Number of overlapping files: {len(train_files & val_files)}")
    
    class_indices = train_gen.class_indices
    X = train_gen.filepaths
    y = train_gen.labels
    
    # Cross-validation setup
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    fold_no = 1
    history_list = []
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1': [],
        'auc': []
    }

    for train_idx, val_idx in kf.split(X, y):
        print(f"\n🔵 Fold {fold_no}")
        
        # Create generators
        simple_datagen = ImageDataGenerator(rescale=1./255)
        train_data = AdvancedDataGenerator(
            [X[i] for i in train_idx],
            [y[i] for i in train_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE
        )
        val_data = AdvancedDataGenerator(
            [X[i] for i in val_idx],
            [y[i] for i in val_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE,
            shuffle=False
        )
        
        # Build model - changed to MobileNetV2
        model = build_enhanced_mobilenet(len(class_indices))
        
        # Callbacks
        callbacks_list = [
            callbacks.EarlyStopping(
                monitor='val_auc',
                patience=15,
                mode='max',
                baseline=0.85,
                restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=1e-6,
                cooldown=2
            ),
            callbacks.ModelCheckpoint(
                f'mobilenet_fold_{fold_no}.keras',  # Changed filename to mobilenet
                monitor='val_auc',
                save_best_only=True,
                mode='max'
            )
        ]
        
        # Train
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=Config.EPOCHS,
            callbacks=callbacks_list,
            verbose=1
        )
        history_list.append(history)
        
        # Evaluate
        val_preds = model.predict(val_data, verbose=0)
        val_preds_labels = np.argmax(val_preds, axis=1)
        val_true_labels = val_data.labels
        
        # Store metrics
        metrics['accuracy'].append(accuracy_score(val_true_labels, val_preds_labels))
        metrics['precision'].append(precision_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['recall'].append(recall_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['f1'].append(f1_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['auc'].append(np.mean(history.history['val_auc'][-5:]))
        
        print(f"✅ Fold {fold_no} Results:")
        print(f"Accuracy: {metrics['accuracy'][-1]*100:.2f}%")
        print(f"AUC: {metrics['auc'][-1]:.4f}")
        
        fold_no += 1
        tf.keras.backend.clear_session()
        gc.collect()
    
    # Final results
    print("\n=== CROSS-VALIDATION RESULTS ===")
    for metric, values in metrics.items():
        print(f"{metric.capitalize()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
    
    return history_list, metrics, class_indices, X, y

# ====== VISUALIZATION ======
def plot_results(history_list, metrics, class_indices, X, y):
    # Training curves
    plt.figure(figsize=(20, 10))
    
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_accuracy'], alpha=0.3, color='orange')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['loss'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_loss'], alpha=0.3, color='orange')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
    # Confusion matrix for best fold
    best_fold = np.argmax(metrics['auc']) + 1
    model = tf.keras.models.load_model(f'mobilenet_fold_{best_fold}.keras')  # Changed to mobilenet
    
    # Get validation data for best fold
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    splits = list(kf.split(X, y))
    _, val_idx = splits[best_fold-1]
    
    val_data = AdvancedDataGenerator(
        [X[i] for i in val_idx],
        [y[i] for i in val_idx],
        ImageDataGenerator(rescale=1./255),
        Config.BATCH_SIZE,
        Config.IMG_SIZE,
        shuffle=False
    )
    
    val_preds = model.predict(val_data)
    val_preds_labels = np.argmax(val_preds, axis=1)
    
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(val_data.labels, val_preds_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_indices.keys(),
                yticklabels=class_indices.keys())
    plt.title(f'MobileNetV2 Confusion Matrix (Fold {best_fold})')  # Changed to MobileNetV2
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# ====== PREDICTION UTILITIES ======
class MobileNetPredictor:  # Changed class name
    def __init__(self, model_path, class_indices):
        self.model = tf.keras.models.load_model(model_path)
        self.class_indices = class_indices
        self.img_size = Config.IMG_SIZE
        
    def predict_image(self, image_path):
        """Make prediction with visualization."""
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Image not found: {image_path}")
            
        img = image.load_img(image_path, target_size=self.img_size)
        img_array = image.img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        pred = self.model.predict(img_array)[0]
        sorted_idx = np.argsort(pred)[::-1]
        
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Input Image')
        
        plt.subplot(1, 2, 2)
        colors = plt.cm.rainbow(np.linspace(0, 1, len(self.class_indices)))
        for i, idx in enumerate(sorted_idx[:3]):
            plt.barh(i, pred[idx]*100, color=colors[idx])
            plt.text(pred[idx]*100 + 1, i, 
                    f"{list(self.class_indices.keys())[idx]}: {pred[idx]*100:.2f}%",
                    va='center')
        plt.yticks([])
        plt.xlabel('Confidence (%)')
        plt.title('Top Predictions')
        plt.xlim(0, 100)
        plt.tight_layout()
        plt.show()
        
        return {list(self.class_indices.keys())[i]: float(pred[i]) for i in sorted_idx}

# ====== MAIN EXECUTION ======
if __name__ == "__main__":
    # Run training
    history_list, metrics, class_indices, X, y = run_training()
    
    # Visualize results
    plot_results(history_list, metrics, class_indices, X, y)
    
    # Example prediction
    predictor = MobileNetPredictor('mobilenet_fold_1.keras', class_indices)  # Changed to mobilenet
    test_image = os.path.join(Config.BASE_DIR, 'NO Dr/005b95c28852.png')
    
    if os.path.exists(test_image):
        print("\nMaking prediction on test image...")
        predictions = predictor.predict_image(test_image)
        print("\nPrediction Probabilities:")
        for cls, prob in predictions.items():
            print(f"{cls}: {prob*100:.2f}%")
    else:
        print(f"\nTest image not found at: {test_image}")
        print("Please provide a valid image path for prediction.")
# Out:
# Found 400 images belonging to 5 classes.
#
# === DATA VALIDATION ===
# Class distribution in training: Counter({0: 80, 1: 80, 2: 80, 3: 80, 4: 80})
# Found 100 images belonging to 5 classes.
# Class distribution in validation: Counter({0: 20, 1: 20, 2: 20, 3: 20, 4: 20})
# Number of overlapping files: 0
#
# 🔵 Fold 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 155ms/step - accuracy: 0.2055 - auc: 0.4743 - loss: 7.1051 - precision: 0.1944 - recall: 0.1452 - val_accuracy: 0.1500 - val_auc: 0.4956 - val_loss: 6.1793 - val_precision: 0.1176 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5565 - auc: 0.8341 - loss: 4.8763 - precision: 0.5774 - recall: 0.5027 - val_accuracy: 0.5500 - val_auc: 0.8887 - val_loss: 4.5463 - val_precision: 0.7018 - val_recall: 0.5000 - learning_rate: 3.0000e-05
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5725 - auc: 0.8471 - loss: 4.7826 - precision: 0.6404 - recall: 0.5057 - val_accuracy: 0.5500 - val_auc: 0.8865 - val_loss: 4.5460 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5542 - auc: 0.8334 - loss: 4.8239 - precision: 0.5912 - recall: 0.4922 - val_accuracy: 0.5375 - val_auc: 0.8865 - val_loss: 4.5355 - val_precision: 0.7222 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5766 - auc: 0.8419 - loss: 4.7853 - precision: 0.6106 - recall: 0.5173 - val_accuracy: 0.5375 - val_auc: 0.8879 - val_loss: 4.5181 - val_precision: 0.6897 - val_recall: 0.5000 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5853 - auc: 0.8368 - loss: 4.8008 - precision: 0.6487 - recall: 0.5030 - val_accuracy: 0.5625 - val_auc: 0.8888 - val_loss: 4.4999 - val_precision: 0.7119 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6025 - auc: 0.8531 - loss: 4.7343 - precision: 0.6550 - recall: 0.5081 - val_accuracy: 0.5625 - val_auc: 0.8894 - val_loss: 4.4894 - val_precision: 0.7241 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5130 - auc: 0.8218 - loss: 4.8607 - precision: 0.5715 - recall: 0.4547 - val_accuracy: 0.5875 - val_auc: 0.8911 - val_loss: 4.4677 - val_precision: 0.7119 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# ✅ Fold 1 Results:
# Accuracy: 58.75%
# AUC: 0.8887
#
# 🔵 Fold 2
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 18s 150ms/step - accuracy: 0.1752 - auc: 0.4940 - loss: 7.0491 - precision: 0.2061 - recall: 0.1469 - val_accuracy: 0.2625 - val_auc: 0.4938 - val_loss: 5.9992 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2249 - auc: 0.5024 - loss: 6.9734 - precision: 0.2106 - recall: 0.1495 - val_accuracy: 0.2750 - val_auc: 0.5511 - val_loss: 5.8905 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.2328 - auc: 0.5210 - loss: 6.7555 - precision: 0.2174 - recall: 0.1490 - val_accuracy: 0.2875 - val_auc: 0.6021 - val_loss: 5.7958 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2761 - auc: 0.5328 - loss: 6.8151 - precision: 0.2606 - recall: 0.2032 - val_accuracy: 0.3500 - val_auc: 0.6494 - val_loss: 5.7082 - val_precision: 0.2500 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.2077 - auc: 0.5426 - loss: 6.6505 - precision: 0.2123 - recall: 0.1455 - val_accuracy: 0.3750 - val_auc: 0.6837 - val_loss: 5.6296 - val_precision: 0.3636 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2605 - auc: 0.5808 - loss: 6.3237 - precision: 0.3095 - recall: 0.2213 - val_accuracy: 0.4000 - val_auc: 0.7142 - val_loss: 5.5555 - val_precision: 0.4000 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2905 - auc: 0.6249 - loss: 6.2027 - precision: 0.3131 - recall: 0.2388 - val_accuracy: 0.4875 - val_auc: 0.7397 - val_loss: 5.4834 - val_precision: 0.4444 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3574 - auc: 0.6523 - loss: 6.1529 - precision: 0.4043 - recall: 0.2914 - val_accuracy: 0.5000 - val_auc: 0.7559 - val_loss: 5.4307 - val_precision: 0.5652 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3216 - auc: 0.6554 - loss: 6.0272 - precision: 0.3478 - recall: 0.2531 - val_accuracy: 0.5000 - val_auc: 0.7700 - val_loss: 5.3804 - val_precision: 0.6071 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3872 - auc: 0.6600 - loss: 6.0942 - precision: 0.4242 - recall: 0.3055 - val_accuracy: 0.5000 - val_auc: 0.7868 - val_loss: 5.3264 - val_precision: 0.6364 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3111 - auc: 0.6411 - loss: 6.1115 - precision: 0.3460 - recall: 0.2378 - val_accuracy: 0.5000 - val_auc: 0.7973 - val_loss: 5.2868 - val_precision: 0.6579 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3492 - auc: 0.6445 - loss: 6.0410 - precision: 0.3857 - recall: 0.2603 - val_accuracy: 0.4875 - val_auc: 0.8113 - val_loss: 5.2370 - val_precision: 0.6757 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.2869 - auc: 0.6484 - loss: 5.9933 - precision: 0.3249 - recall: 0.2336 - val_accuracy: 0.5250 - val_auc: 0.8205 - val_loss: 5.1918 - val_precision: 0.6512 - val_recall: 0.3500 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3744 - auc: 0.6733 - loss: 5.9702 - precision: 0.4136 - recall: 0.2885 - val_accuracy: 0.5250 - val_auc: 0.8260 - val_loss: 5.1603 - val_precision: 0.6591 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3136 - auc: 0.6397 - loss: 6.0809 - precision: 0.3478 - recall: 0.2594 - val_accuracy: 0.5125 - val_auc: 0.8297 - val_loss: 5.1346 - val_precision: 0.6818 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3951 - auc: 0.6946 - loss: 5.8163 - precision: 0.4548 - recall: 0.3429 - val_accuracy: 0.5000 - val_auc: 0.8367 - val_loss: 5.0982 - val_precision: 0.6809 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3903 - auc: 0.7015 - loss: 5.7118 - precision: 0.5071 - recall: 0.3202 - val_accuracy: 0.5125 - val_auc: 0.8395 - val_loss: 5.0722 - val_precision: 0.6800 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3916 - auc: 0.6924 - loss: 5.8110 - precision: 0.4189 - recall: 0.3188 - val_accuracy: 0.5250 - val_auc: 0.8433 - val_loss: 5.0429 - val_precision: 0.6731 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4319 - auc: 0.7337 - loss: 5.5928 - precision: 0.4952 - recall: 0.3843 - val_accuracy: 0.5375 - val_auc: 0.8463 - val_loss: 5.0202 - val_precision: 0.7000 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3622 - auc: 0.6839 - loss: 5.7899 - precision: 0.3871 - recall: 0.2914 - val_accuracy: 0.5500 - val_auc: 0.8505 - val_loss: 4.9958 - val_precision: 0.7000 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3889 - auc: 0.7220 - loss: 5.5850 - precision: 0.4407 - recall: 0.3440 - val_accuracy: 0.5375 - val_auc: 0.8537 - val_loss: 4.9712 - val_precision: 0.7083 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4556 - auc: 0.7664 - loss: 5.4079 - precision: 0.4892 - recall: 0.3465 - val_accuracy: 0.5375 - val_auc: 0.8570 - val_loss: 4.9445 - val_precision: 0.7021 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4279 - auc: 0.7206 - loss: 5.5874 - precision: 0.4458 - recall: 0.3343 - val_accuracy: 0.5375 - val_auc: 0.8591 - val_loss: 4.9208 - val_precision: 0.7021 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5277 - auc: 0.7869 - loss: 5.0352 - precision: 0.5208 - recall: 0.4170 - val_accuracy: 0.6750 - val_auc: 0.8954 - val_loss: 4.4863 - val_precision: 0.6842 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5297 - auc: 0.8197 - loss: 4.9269 - precision: 0.5548 - recall: 0.4754 - val_accuracy: 0.6875 - val_auc: 0.8978 - val_loss: 4.4693 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5091 - auc: 0.8186 - loss: 4.8572 - precision: 0.5653 - recall: 0.4349 - val_accuracy: 0.6875 - val_auc: 0.8979 - val_loss: 4.4559 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5054 - auc: 0.8140 - loss: 4.9088 - precision: 0.5501 - recall: 0.4511 - val_accuracy: 0.6875 - val_auc: 0.8994 - val_loss: 4.4399 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5407 - auc: 0.8098 - loss: 4.9346 - precision: 0.5718 - recall: 0.4815 - val_accuracy: 0.7000 - val_auc: 0.9000 - val_loss: 4.4260 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5974 - auc: 0.8282 - loss: 4.7945 - precision: 0.6261 - recall: 0.5397 - val_accuracy: 0.7000 - val_auc: 0.9007 - val_loss: 4.4069 - val_precision: 0.6964 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# ✅ Fold 2 Results:
# Accuracy: 70.00%
# AUC: 0.8992
#
# 🔵 Fold 3
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 19s 155ms/step - accuracy: 0.2390 - auc: 0.5159 - loss: 6.8925 - precision: 0.2412 - recall: 0.1697 - val_accuracy: 0.3375 - val_auc: 0.7273 - val_loss: 5.6324 - val_precision: 1.0000 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2768 - auc: 0.5672 - loss: 6.5477 - precision: 0.2865 - recall: 0.2058 - val_accuracy: 0.4375 - val_auc: 0.7963 - val_loss: 5.4890 - val_precision: 1.0000 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.2755 - auc: 0.5895 - loss: 6.5333 - precision: 0.2899 - recall: 0.2115 - val_accuracy: 0.5250 - val_auc: 0.8349 - val_loss: 5.3809 - val_precision: 1.0000 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.2109 - auc: 0.5524 - loss: 6.5445 - precision: 0.2467 - recall: 0.1675 - val_accuracy: 0.5500 - val_auc: 0.8657 - val_loss: 5.2840 - val_precision: 0.9500 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.2332 - auc: 0.5964 - loss: 6.3259 - precision: 0.2620 - recall: 0.1904 - val_accuracy: 0.6000 - val_auc: 0.8828 - val_loss: 5.1920 - val_precision: 0.9643 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2434 - auc: 0.6194 - loss: 6.3254 - precision: 0.2921 - recall: 0.2116 - val_accuracy: 0.6500 - val_auc: 0.8940 - val_loss: 5.1204 - val_precision: 0.9706 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3508 - auc: 0.6799 - loss: 5.9999 - precision: 0.3902 - recall: 0.2959 - val_accuracy: 0.6625 - val_auc: 0.9001 - val_loss: 5.0682 - val_precision: 0.9459 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3136 - auc: 0.6056 - loss: 6.4222 - precision: 0.3166 - recall: 0.2240 - val_accuracy: 0.6625 - val_auc: 0.9046 - val_loss: 5.0188 - val_precision: 0.9024 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3026 - auc: 0.6065 - loss: 6.2826 - precision: 0.2996 - recall: 0.2045 - val_accuracy: 0.6875 - val_auc: 0.9129 - val_loss: 4.9620 - val_precision: 0.9333 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3264 - auc: 0.6563 - loss: 6.1287 - precision: 0.3383 - recall: 0.2378 - val_accuracy: 0.7000 - val_auc: 0.9189 - val_loss: 4.9138 - val_precision: 0.9130 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3461 - auc: 0.6486 - loss: 6.0394 - precision: 0.3532 - recall: 0.2609 - val_accuracy: 0.7000 - val_auc: 0.9215 - val_loss: 4.8788 - val_precision: 0.9130 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3728 - auc: 0.6976 - loss: 5.8889 - precision: 0.4140 - recall: 0.3148 - val_accuracy: 0.7000 - val_auc: 0.9244 - val_loss: 4.8461 - val_precision: 0.9333 - val_recall: 0.5250 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3902 - auc: 0.6501 - loss: 6.0978 - precision: 0.4039 - recall: 0.2927 - val_accuracy: 0.7000 - val_auc: 0.9261 - val_loss: 4.8146 - val_precision: 0.9149 - val_recall: 0.5375 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3632 - auc: 0.6731 - loss: 5.8904 - precision: 0.4241 - recall: 0.3065 - val_accuracy: 0.7000 - val_auc: 0.9270 - val_loss: 4.7875 - val_precision: 0.8800 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3549 - auc: 0.6766 - loss: 5.8978 - precision: 0.4087 - recall: 0.2810 - val_accuracy: 0.6875 - val_auc: 0.9278 - val_loss: 4.7602 - val_precision: 0.8824 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3100 - auc: 0.6582 - loss: 6.0508 - precision: 0.3360 - recall: 0.2548 - val_accuracy: 0.7000 - val_auc: 0.9302 - val_loss: 4.7364 - val_precision: 0.8980 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3724 - auc: 0.6821 - loss: 5.8769 - precision: 0.4066 - recall: 0.2934 - val_accuracy: 0.7000 - val_auc: 0.9315 - val_loss: 4.7092 - val_precision: 0.8800 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4667 - auc: 0.7670 - loss: 5.4559 - precision: 0.4945 - recall: 0.3833 - val_accuracy: 0.7125 - val_auc: 0.9322 - val_loss: 4.6889 - val_precision: 0.8824 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3787 - auc: 0.6988 - loss: 5.7157 - precision: 0.4691 - recall: 0.3347 - val_accuracy: 0.7000 - val_auc: 0.9328 - val_loss: 4.6687 - val_precision: 0.8824 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4553 - auc: 0.7748 - loss: 5.3550 - precision: 0.5371 - recall: 0.3738 - val_accuracy: 0.7125 - val_auc: 0.9333 - val_loss: 4.6482 - val_precision: 0.8824 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4447 - auc: 0.7449 - loss: 5.5849 - precision: 0.5023 - recall: 0.3911 - val_accuracy: 0.7125 - val_auc: 0.9344 - val_loss: 4.6288 - val_precision: 0.8824 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4898 - auc: 0.7613 - loss: 5.5150 - precision: 0.5350 - recall: 0.4128 - val_accuracy: 0.7125 - val_auc: 0.9334 - val_loss: 4.6147 - val_precision: 0.8846 - val_recall: 0.5750 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.4219 - auc: 0.7397 - loss: 5.5488 - precision: 0.4544 - recall: 0.3437 - val_accuracy: 0.7125 - val_auc: 0.9330 - val_loss: 4.6021 - val_precision: 0.8545 - val_recall: 0.5875 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4348 - auc: 0.7581 - loss: 5.4702 - precision: 0.4744 - recall: 0.3895 - val_accuracy: 0.7250 - val_auc: 0.9339 - val_loss: 4.5799 - val_precision: 0.8571 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5512 - auc: 0.8347 - loss: 4.7895 - precision: 0.5975 - recall: 0.4585 - val_accuracy: 0.6875 - val_auc: 0.9365 - val_loss: 4.2433 - val_precision: 0.7966 - val_recall: 0.5875 - learning_rate: 3.0000e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4986 - auc: 0.7788 - loss: 5.1149 - precision: 0.5102 - recall: 0.4132 - val_accuracy: 0.6750 - val_auc: 0.9364 - val_loss: 4.2350 - val_precision: 0.7869 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5240 - auc: 0.8086 - loss: 4.9253 - precision: 0.5776 - recall: 0.4611 - val_accuracy: 0.6875 - val_auc: 0.9376 - val_loss: 4.2181 - val_precision: 0.7778 - val_recall: 0.6125 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5821 - auc: 0.8400 - loss: 4.7358 - precision: 0.6102 - recall: 0.4766 - val_accuracy: 0.6875 - val_auc: 0.9374 - val_loss: 4.2022 - val_precision: 0.7903 - val_recall: 0.6125 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5381 - auc: 0.8246 - loss: 4.8110 - precision: 0.5738 - recall: 0.4794 - val_accuracy: 0.6875 - val_auc: 0.9382 - val_loss: 4.1875 - val_precision: 0.8033 - val_recall: 0.6125 - learning_rate: 3.0000e-05
# ✅ Fold 3 Results:
# Accuracy: 70.00%
# AUC: 0.9372
#
# 🔵 Fold 4
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 18s 155ms/step - accuracy: 0.1647 - auc: 0.5056 - loss: 6.8463 - precision: 0.1809 - recall: 0.1225 - val_accuracy: 0.2125 - val_auc: 0.5087 - val_loss: 6.1306 - val_precision: 0.0909 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.2058 - auc: 0.5189 - loss: 6.7757 - precision: 0.2394 - recall: 0.1692 - val_accuracy: 0.3000 - val_auc: 0.5878 - val_loss: 5.8555 - val_precision: 0.1000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.1782 - auc: 0.5112 - loss: 6.8037 - precision: 0.2182 - recall: 0.1520 - val_accuracy: 0.3500 - val_auc: 0.6661 - val_loss: 5.6961 - val_precision: 0.2857 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2320 - auc: 0.5528 - loss: 6.6187 - precision: 0.2521 - recall: 0.1830 - val_accuracy: 0.3625 - val_auc: 0.7259 - val_loss: 5.5889 - val_precision: 0.4286 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2237 - auc: 0.5523 - loss: 6.7231 - precision: 0.2620 - recall: 0.1892 - val_accuracy: 0.3875 - val_auc: 0.7631 - val_loss: 5.5029 - val_precision: 0.5455 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2910 - auc: 0.5708 - loss: 6.5103 - precision: 0.2903 - recall: 0.2121 - val_accuracy: 0.4500 - val_auc: 0.7893 - val_loss: 5.4233 - val_precision: 0.5556 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3264 - auc: 0.6260 - loss: 6.1671 - precision: 0.3303 - recall: 0.2387 - val_accuracy: 0.5000 - val_auc: 0.8103 - val_loss: 5.3598 - val_precision: 0.6316 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.2689 - auc: 0.5836 - loss: 6.3897 - precision: 0.2832 - recall: 0.1953 - val_accuracy: 0.5125 - val_auc: 0.8233 - val_loss: 5.3023 - val_precision: 0.7083 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.3193 - auc: 0.6374 - loss: 6.1206 - precision: 0.3261 - recall: 0.2352 - val_accuracy: 0.5875 - val_auc: 0.8316 - val_loss: 5.2547 - val_precision: 0.7308 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4166 - auc: 0.6994 - loss: 5.9141 - precision: 0.4411 - recall: 0.3329 - val_accuracy: 0.5625 - val_auc: 0.8411 - val_loss: 5.2070 - val_precision: 0.7241 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2941 - auc: 0.6582 - loss: 6.0328 - precision: 0.3201 - recall: 0.2461 - val_accuracy: 0.5375 - val_auc: 0.8488 - val_loss: 5.1649 - val_precision: 0.7000 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3268 - auc: 0.6861 - loss: 5.8729 - precision: 0.3520 - recall: 0.2666 - val_accuracy: 0.5625 - val_auc: 0.8559 - val_loss: 5.1259 - val_precision: 0.6970 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3701 - auc: 0.7035 - loss: 5.7993 - precision: 0.3792 - recall: 0.2711 - val_accuracy: 0.5375 - val_auc: 0.8613 - val_loss: 5.0894 - val_precision: 0.6923 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2744 - auc: 0.6520 - loss: 6.1349 - precision: 0.3146 - recall: 0.2293 - val_accuracy: 0.5750 - val_auc: 0.8631 - val_loss: 5.0601 - val_precision: 0.6905 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3328 - auc: 0.6867 - loss: 5.9082 - precision: 0.3772 - recall: 0.2765 - val_accuracy: 0.6000 - val_auc: 0.8631 - val_loss: 5.0382 - val_precision: 0.6818 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4268 - auc: 0.7356 - loss: 5.6371 - precision: 0.4488 - recall: 0.3439 - val_accuracy: 0.5750 - val_auc: 0.8668 - val_loss: 5.0071 - val_precision: 0.6957 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3745 - auc: 0.7056 - loss: 5.8115 - precision: 0.4204 - recall: 0.3374 - val_accuracy: 0.5625 - val_auc: 0.8754 - val_loss: 4.9671 - val_precision: 0.6957 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3689 - auc: 0.6932 - loss: 5.7532 - precision: 0.4212 - recall: 0.3077 - val_accuracy: 0.5625 - val_auc: 0.8731 - val_loss: 4.9522 - val_precision: 0.6939 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.4127 - auc: 0.7243 - loss: 5.6967 - precision: 0.4684 - recall: 0.3493 - val_accuracy: 0.5750 - val_auc: 0.8734 - val_loss: 4.9339 - val_precision: 0.6731 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 20/50
# ...
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5965 - auc: 0.8539 - loss: 4.7124 - precision: 0.6613 - recall: 0.5326 - val_accuracy: 0.5625 - val_auc: 0.9026 - val_loss: 4.4232 - val_precision: 0.6786 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6087 - auc: 0.8468 - loss: 4.7547 - precision: 0.6366 - recall: 0.5105 - val_accuracy: 0.5875 - val_auc: 0.9020 - val_loss: 4.4134 - val_precision: 0.6610 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.4966 - auc: 0.8209 - loss: 4.8384 - precision: 0.5532 - recall: 0.4355 - val_accuracy: 0.6000 - val_auc: 0.9025 - val_loss: 4.3964 - val_precision: 0.6610 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.5913 - auc: 0.8594 - loss: 4.6538 - precision: 0.6260 - recall: 0.5144 - val_accuracy: 0.5750 - val_auc: 0.9041 - val_loss: 4.3710 - val_precision: 0.6721 - val_recall: 0.5125 - learning_rate: 3.0000e-05
# ✅ Fold 4 Results:
# Accuracy: 57.50%
# AUC: 0.9029
#
# 🔵 Fold 5
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 18s 154ms/step - accuracy: 0.2258 - auc: 0.5087 - loss: 7.0351 - precision: 0.2430 - recall: 0.1616 - val_accuracy: 0.2000 - val_auc: 0.5613 - val_loss: 5.9563 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2038 - auc: 0.5236 - loss: 6.7407 - precision: 0.2077 - recall: 0.1457 - val_accuracy: 0.2000 - val_auc: 0.6076 - val_loss: 5.8157 - val_precision: 0.1818 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2400 - auc: 0.5551 - loss: 6.6682 - precision: 0.2427 - recall: 0.1758 - val_accuracy: 0.2500 - val_auc: 0.6538 - val_loss: 5.7224 - val_precision: 0.3889 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2969 - auc: 0.5902 - loss: 6.4938 - precision: 0.3002 - recall: 0.2156 - val_accuracy: 0.2625 - val_auc: 0.6781 - val_loss: 5.6650 - val_precision: 0.3810 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2746 - auc: 0.5810 - loss: 6.5250 - precision: 0.2788 - recall: 0.2018 - val_accuracy: 0.3375 - val_auc: 0.7040 - val_loss: 5.6027 - val_precision: 0.4348 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3730 - auc: 0.6369 - loss: 6.2523 - precision: 0.3727 - recall: 0.2635 - val_accuracy: 0.4000 - val_auc: 0.7257 - val_loss: 5.5402 - val_precision: 0.5000 - val_recall: 0.1750 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.2791 - auc: 0.6018 - loss: 6.3934 - precision: 0.2872 - recall: 0.2162 - val_accuracy: 0.4125 - val_auc: 0.7394 - val_loss: 5.4953 - val_precision: 0.5161 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3276 - auc: 0.6562 - loss: 6.0851 - precision: 0.3444 - recall: 0.2631 - val_accuracy: 0.4250 - val_auc: 0.7446 - val_loss: 5.4739 - val_precision: 0.5135 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.4134 - auc: 0.7073 - loss: 5.8342 - precision: 0.4513 - recall: 0.3077 - val_accuracy: 0.4250 - val_auc: 0.7591 - val_loss: 5.4265 - val_precision: 0.5366 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3501 - auc: 0.6269 - loss: 6.2060 - precision: 0.4043 - recall: 0.2700 - val_accuracy: 0.4125 - val_auc: 0.7714 - val_loss: 5.3814 - val_precision: 0.5610 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.2923 - auc: 0.6297 - loss: 6.2256 - precision: 0.3162 - recall: 0.2407 - val_accuracy: 0.4375 - val_auc: 0.7769 - val_loss: 5.3604 - val_precision: 0.5217 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4539 - auc: 0.7469 - loss: 5.6048 - precision: 0.4975 - recall: 0.3921 - val_accuracy: 0.4875 - val_auc: 0.8339 - val_loss: 5.0376 - val_precision: 0.5962 - val_recall: 0.3875 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4683 - auc: 0.7651 - loss: 5.4655 - precision: 0.5317 - recall: 0.4279 - val_accuracy: 0.4875 - val_auc: 0.8371 - val_loss: 5.0125 - val_precision: 0.6038 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4302 - auc: 0.7429 - loss: 5.5629 - precision: 0.4606 - recall: 0.3570 - val_accuracy: 0.4875 - val_auc: 0.8384 - val_loss: 4.9983 - val_precision: 0.6038 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4756 - auc: 0.7900 - loss: 5.3710 - precision: 0.5085 - recall: 0.4008 - val_accuracy: 0.5000 - val_auc: 0.8427 - val_loss: 4.9670 - val_precision: 0.5926 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4648 - auc: 0.7609 - loss: 5.4571 - precision: 0.4865 - recall: 0.3747 - val_accuracy: 0.5000 - val_auc: 0.8476 - val_loss: 4.9258 - val_precision: 0.6154 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4762 - auc: 0.7627 - loss: 5.4511 - precision: 0.5679 - recall: 0.4343 - val_accuracy: 0.5000 - val_auc: 0.8490 - val_loss: 4.9065 - val_precision: 0.5893 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.4941 - auc: 0.8080 - loss: 5.2331 - precision: 0.5215 - recall: 0.4312 - val_accuracy: 0.5000 - val_auc: 0.8503 - val_loss: 4.8934 - val_precision: 0.5893 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5084 - auc: 0.8186 - loss: 5.1362 - precision: 0.5559 - recall: 0.4579 - val_accuracy: 0.5250 - val_auc: 0.8560 - val_loss: 4.8541 - val_precision: 0.5932 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4980 - auc: 0.7986 - loss: 5.2375 - precision: 0.5199 - recall: 0.4269 - val_accuracy: 0.5250 - val_auc: 0.8569 - val_loss: 4.8426 - val_precision: 0.5902 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5403 - auc: 0.8295 - loss: 5.0699 - precision: 0.5955 - recall: 0.4883 - val_accuracy: 0.5250 - val_auc: 0.8561 - val_loss: 4.8329 - val_precision: 0.5932 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5439 - auc: 0.8065 - loss: 5.1711 - precision: 0.6035 - recall: 0.4906 - val_accuracy: 0.5375 - val_auc: 0.8586 - val_loss: 4.8088 - val_precision: 0.5968 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5440 - auc: 0.8091 - loss: 5.1790 - precision: 0.5638 - recall: 0.4562 - val_accuracy: 0.5250 - val_auc: 0.8579 - val_loss: 4.7999 - val_precision: 0.6129 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5367 - auc: 0.8250 - loss: 5.0631 - precision: 0.5719 - recall: 0.5033 - val_accuracy: 0.5250 - val_auc: 0.8569 - val_loss: 4.7898 - val_precision: 0.5968 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4922 - auc: 0.7766 - loss: 5.2873 - precision: 0.5589 - recall: 0.4626 - val_accuracy: 0.5375 - val_auc: 0.8593 - val_loss: 4.7681 - val_precision: 0.5968 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5842 - auc: 0.8351 - loss: 5.0312 - precision: 0.6311 - recall: 0.5310 - val_accuracy: 0.5250 - val_auc: 0.8619 - val_loss: 4.7480 - val_precision: 0.5968 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.5583 - auc: 0.8360 - loss: 4.9950 - precision: 0.6075 - recall: 0.4872 - val_accuracy: 0.5375 - val_auc: 0.8661 - val_loss: 4.7173 - val_precision: 0.6167 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5142 - auc: 0.8234 - loss: 4.9929 - precision: 0.5759 - recall: 0.4716 - val_accuracy: 0.5500 - val_auc: 0.8704 - val_loss: 4.6816 - val_precision: 0.6290 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5296 - auc: 0.8244 - loss: 4.9935 - precision: 0.5899 - recall: 0.4639 - val_accuracy: 0.5625 - val_auc: 0.8710 - val_loss: 4.6648 - val_precision: 0.6393 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5698 - auc: 0.8456 - loss: 4.8729 - precision: 0.6095 - recall: 0.5143 - val_accuracy: 0.5500 - val_auc: 0.8724 - val_loss: 4.6475 - val_precision: 0.6066 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.6008 - auc: 0.8353 - loss: 4.9270 - precision: 0.6510 - recall: 0.5269 - val_accuracy: 0.5500 - val_auc: 0.8760 - val_loss: 4.6208 - val_precision: 0.6271 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4902 - auc: 0.8116 - loss: 5.0061 - precision: 0.5271 - recall: 0.4393 - val_accuracy: 0.5750 - val_auc: 0.8789 - val_loss: 4.5968 - val_precision: 0.6491 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4906 - auc: 0.8107 - loss: 5.0523 - precision: 0.5458 - recall: 0.4355 - val_accuracy: 0.5625 - val_auc: 0.8805 - val_loss: 4.5783 - val_precision: 0.6441 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.5172 - auc: 0.8070 - loss: 5.0652 - precision: 0.5643 - recall: 0.4646 - val_accuracy: 0.5750 - val_auc: 0.8823 - val_loss: 4.5522 - val_precision: 0.6441 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5518 - auc: 0.8435 - loss: 4.8185 - precision: 0.6114 - recall: 0.4973 - val_accuracy: 0.5750 - val_auc: 0.8806 - val_loss: 4.5514 - val_precision: 0.6379 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.6240 - auc: 0.8600 - loss: 4.7062 - precision: 0.6760 - recall: 0.5781 - val_accuracy: 0.5875 - val_auc: 0.8822 - val_loss: 4.5319 - val_precision: 0.6333 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.5712 - auc: 0.8413 - loss: 4.8357 - precision: 0.5902 - recall: 0.4963 - val_accuracy: 0.6000 - val_auc: 0.8813 - val_loss: 4.5226 - val_precision: 0.6441 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5529 - auc: 0.8355 - loss: 4.8467 - precision: 0.6305 - recall: 0.5290 - val_accuracy: 0.6000 - val_auc: 0.8808 - val_loss: 4.5183 - val_precision: 0.6500 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.5617 - auc: 0.8294 - loss: 4.8656 - precision: 0.5834 - recall: 0.4944 - val_accuracy: 0.6000 - val_auc: 0.8790 - val_loss: 4.5085 - val_precision: 0.6333 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6103 - auc: 0.8590 - loss: 4.6758 - precision: 0.6574 - recall: 0.5343 - val_accuracy: 0.6000 - val_auc: 0.8773 - val_loss: 4.5060 - val_precision: 0.6441 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# ✅ Fold 5 Results:
# Accuracy: 57.50%
# AUC: 0.8801
#
# === CROSS-VALIDATION RESULTS ===
# Accuracy: 0.6275 ± 0.0594
# Precision: 0.6814 ± 0.0447
# Recall: 0.6275 ± 0.0594
# F1: 0.6058 ± 0.0686
# Auc: 0.9016 ± 0.0195
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step
# Making prediction on test image...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Prediction Probabilities:
# NO Dr: 98.43%
# Moderate: 0.56%
# Proliferative_DR: 0.51%
# Mild: 0.30%
# Severe Dr: 0.19%
