# %%
import tensorflow as tf
from tensorflow.keras.applications import NASNetMobile  # Changed to NASNetMobile
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, confusion_matrix, 
                           precision_score, recall_score, f1_score, 
                           accuracy_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc
import math
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
from collections import Counter

# ====== CONFIGURATION ======
class Config:
    BATCH_SIZE = 8
    IMG_SIZE = (224, 224)  # NASNetMobile can use 224x224
    NUM_FOLDS = 5
    EPOCHS = 50
    LEARNING_RATE = 3e-5
    DROPOUT_RATE = 0.5
    SE_RATIO = 16
    BASE_DIR = '/kaggle/input/local-preprocessed-dataset/LOCAL PREPROCESSED DATASET'
    SEED = 42
    MIN_SAMPLES = 20

# ====== DATA AUGMENTATION ======
def create_augmenter():
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.95, 1.05],
        fill_mode='reflect',
        validation_split=0.2
    )

# ====== SQUEEZE-EXCITATION BLOCK ======
def se_block(input_tensor, ratio=Config.SE_RATIO):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(channels // ratio, activation='relu', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    
    return layers.Multiply()([input_tensor, se])

# ====== ENHANCED NASNETMOBILE MODEL ======
def build_enhanced_nasnet(num_classes):
    base_model = NASNetMobile(
        weights='imagenet',
        include_top=False,
        input_shape=(*Config.IMG_SIZE, 3)
    )
    
    # Freeze all convolutional layers
    for layer in base_model.layers:
        layer.trainable = False
    
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    x = layers.Dense(256, activation='relu', 
                    kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=outputs)
    
    optimizer = optimizers.Adam(
        learning_rate=Config.LEARNING_RATE,
        clipnorm=1.0
    )
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')]
    )
    
    return model

# ====== CUSTOM DATA GENERATOR ======
class AdvancedDataGenerator(Sequence):
    def __init__(self, filepaths, labels, datagen, batch_size=32, img_size=(224,224), shuffle=True):
        self.filepaths = filepaths
        self.labels = labels
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.filepaths) / self.batch_size)

    def __getitem__(self, index):
        batch_files = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        images = []
        for filepath in batch_files:
            img = image.load_img(filepath, target_size=self.img_size)
            img_array = image.img_to_array(img)
            img_array = self.datagen.standardize(img_array)
            images.append(img_array)
            
        return np.array(images), tf.keras.utils.to_categorical(batch_labels, num_classes=len(set(self.labels)))

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.filepaths))
            np.random.shuffle(indices)
            self.filepaths = [self.filepaths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# ====== TRAINING PIPELINE ======
def run_training():
    # Initialize data
    datagen = create_augmenter()
    train_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=Config.SEED
    )
    
    # Data integrity checks
    print("\n=== DATA VALIDATION ===")
    print("Class distribution in training:", Counter(train_gen.labels))
    
    val_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=Config.SEED
    )
    print("Class distribution in validation:", Counter(val_gen.labels))
    
    # Verify no overlap
    train_files = set(train_gen.filepaths)
    val_files = set(val_gen.filepaths)
    print(f"Number of overlapping files: {len(train_files & val_files)}")
    
    class_indices = train_gen.class_indices
    X = train_gen.filepaths
    y = train_gen.labels
    
    # Cross-validation setup
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    fold_no = 1
    history_list = []
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1': [],
        'auc': []
    }

    for train_idx, val_idx in kf.split(X, y):
        print(f"\n🔵 Fold {fold_no}")
        
        # Create generators
        simple_datagen = ImageDataGenerator(rescale=1./255)
        train_data = AdvancedDataGenerator(
            [X[i] for i in train_idx],
            [y[i] for i in train_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE
        )
        val_data = AdvancedDataGenerator(
            [X[i] for i in val_idx],
            [y[i] for i in val_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE,
            shuffle=False
        )
        
        # Build model - changed to NASNetMobile
        model = build_enhanced_nasnet(len(class_indices))
        
        # Callbacks
        callbacks_list = [
            callbacks.EarlyStopping(
                monitor='val_auc',
                patience=15,
                mode='max',
                baseline=0.85,
                restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=1e-6,
                cooldown=2
            ),
            callbacks.ModelCheckpoint(
                f'nasnet_fold_{fold_no}.keras',  # Changed filename to nasnet
                monitor='val_auc',
                save_best_only=True,
                mode='max'
            )
        ]
        
        # Train
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=Config.EPOCHS,
            callbacks=callbacks_list,
            verbose=1
        )
        history_list.append(history)
        
        # Evaluate
        val_preds = model.predict(val_data, verbose=0)
        val_preds_labels = np.argmax(val_preds, axis=1)
        val_true_labels = val_data.labels
        
        # Store metrics
        metrics['accuracy'].append(accuracy_score(val_true_labels, val_preds_labels))
        metrics['precision'].append(precision_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['recall'].append(recall_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['f1'].append(f1_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['auc'].append(np.mean(history.history['val_auc'][-5:]))
        
        print(f"✅ Fold {fold_no} Results:")
        print(f"Accuracy: {metrics['accuracy'][-1]*100:.2f}%")
        print(f"AUC: {metrics['auc'][-1]:.4f}")
        
        fold_no += 1
        tf.keras.backend.clear_session()
        gc.collect()
    
    # Final results
    print("\n=== CROSS-VALIDATION RESULTS ===")
    for metric, values in metrics.items():
        print(f"{metric.capitalize()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
    
    return history_list, metrics, class_indices, X, y

# ====== VISUALIZATION ======
def plot_results(history_list, metrics, class_indices, X, y):
    # Training curves
    plt.figure(figsize=(20, 10))
    
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_accuracy'], alpha=0.3, color='orange')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['loss'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_loss'], alpha=0.3, color='orange')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
    # Confusion matrix for best fold
    best_fold = np.argmax(metrics['auc']) + 1
    model = tf.keras.models.load_model(f'nasnet_fold_{best_fold}.keras')  # Changed to nasnet
    
    # Get validation data for best fold
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    splits = list(kf.split(X, y))
    _, val_idx = splits[best_fold-1]
    
    val_data = AdvancedDataGenerator(
        [X[i] for i in val_idx],
        [y[i] for i in val_idx],
        ImageDataGenerator(rescale=1./255),
        Config.BATCH_SIZE,
        Config.IMG_SIZE,
        shuffle=False
    )
    
    val_preds = model.predict(val_data)
    val_preds_labels = np.argmax(val_preds, axis=1)
    
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(val_data.labels, val_preds_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_indices.keys(),
                yticklabels=class_indices.keys())
    plt.title(f'NASNetMobile Confusion Matrix (Fold {best_fold})')  # Changed to NASNetMobile
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# ====== PREDICTION UTILITIES ======
class NASNetPredictor:  # Changed class name
    def __init__(self, model_path, class_indices):
        self.model = tf.keras.models.load_model(model_path)
        self.class_indices = class_indices
        self.img_size = Config.IMG_SIZE
        
    def predict_image(self, image_path):
        """Make prediction with visualization."""
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Image not found: {image_path}")
            
        img = image.load_img(image_path, target_size=self.img_size)
        img_array = image.img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        pred = self.model.predict(img_array)[0]
        sorted_idx = np.argsort(pred)[::-1]
        
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Input Image')
        
        plt.subplot(1, 2, 2)
        colors = plt.cm.rainbow(np.linspace(0, 1, len(self.class_indices)))
        for i, idx in enumerate(sorted_idx[:3]):
            plt.barh(i, pred[idx]*100, color=colors[idx])
            plt.text(pred[idx]*100 + 1, i, 
                    f"{list(self.class_indices.keys())[idx]}: {pred[idx]*100:.2f}%",
                    va='center')
        plt.yticks([])
        plt.xlabel('Confidence (%)')
        plt.title('Top Predictions')
        plt.xlim(0, 100)
        plt.tight_layout()
        plt.show()
        
        return {list(self.class_indices.keys())[i]: float(pred[i]) for i in sorted_idx}

# ====== MAIN EXECUTION ======
if __name__ == "__main__":
    # Run training
    history_list, metrics, class_indices, X, y = run_training()
    
    # Visualize results
    plot_results(history_list, metrics, class_indices, X, y)
    
    # Example prediction
    predictor = NASNetPredictor('nasnet_fold_1.keras', class_indices)  # Changed to nasnet
    test_image = os.path.join(Config.BASE_DIR, 'NO Dr/005b95c28852.png')
    
    if os.path.exists(test_image):
        print("\nMaking prediction on test image...")
        predictions = predictor.predict_image(test_image)
        print("\nPrediction Probabilities:")
        for cls, prob in predictions.items():
            print(f"{cls}: {prob*100:.2f}%")
    else:
        print(f"\nTest image not found at: {test_image}")
        print("Please provide a valid image path for prediction.")
# Out:
# Found 400 images belonging to 5 classes.
#
# === DATA VALIDATION ===
# Class distribution in training: Counter({0: 80, 1: 80, 2: 80, 3: 80, 4: 80})
# Found 100 images belonging to 5 classes.
# Class distribution in validation: Counter({0: 20, 1: 20, 2: 20, 3: 20, 4: 20})
# Number of overlapping files: 0
#
# 🔵 Fold 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 67s 503ms/step - accuracy: 0.1753 - auc: 0.4863 - loss: 6.7700 - precision: 0.1634 - recall: 0.1091 - val_accuracy: 0.2750 - val_auc: 0.5891 - val_loss: 5.7546 - val_precision: 0.2308 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3311 - auc: 0.6325 - loss: 6.0057 - precision: 0.3475 - recall: 0.2500 - val_accuracy: 0.5000 - val_auc: 0.7575 - val_loss: 5.3118 - val_precision: 0.5789 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.3665 - auc: 0.6556 - loss: 5.9158 - precision: 0.3618 - recall: 0.2731 - val_accuracy: 0.5000 - val_auc: 0.7635 - val_loss: 5.2811 - val_precision: 0.6098 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3592 - auc: 0.6986 - loss: 5.7622 - precision: 0.3961 - recall: 0.3004 - val_accuracy: 0.5000 - val_auc: 0.7739 - val_loss: 5.2463 - val_precision: 0.6000 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3949 - auc: 0.6728 - loss: 5.8410 - precision: 0.4044 - recall: 0.2711 - val_accuracy: 0.5000 - val_auc: 0.7715 - val_loss: 5.2520 - val_precision: 0.6000 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# ✅ Fold 1 Results:
# Accuracy: 50.00%
# AUC: 0.7635
#
# 🔵 Fold 2
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 62s 507ms/step - accuracy: 0.2200 - auc: 0.5125 - loss: 6.7036 - precision: 0.2352 - recall: 0.1660 - val_accuracy: 0.2625 - val_auc: 0.6335 - val_loss: 5.6394 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2018 - auc: 0.5184 - loss: 6.6716 - precision: 0.2227 - recall: 0.1454 - val_accuracy: 0.3000 - val_auc: 0.6747 - val_loss: 5.5735 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2538 - auc: 0.5694 - loss: 6.3206 - precision: 0.2794 - recall: 0.1862 - val_accuracy: 0.3250 - val_auc: 0.7048 - val_loss: 5.5175 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2118 - auc: 0.5297 - loss: 6.5448 - precision: 0.2222 - recall: 0.1505 - val_accuracy: 0.3750 - val_auc: 0.7317 - val_loss: 5.4598 - val_precision: 0.6250 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.2524 - auc: 0.5661 - loss: 6.4680 - precision: 0.2233 - recall: 0.1549 - val_accuracy: 0.3750 - val_auc: 0.7492 - val_loss: 5.4103 - val_precision: 0.5000 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4783 - auc: 0.8105 - loss: 4.9904 - precision: 0.5617 - recall: 0.4414 - val_accuracy: 0.5375 - val_auc: 0.8754 - val_loss: 4.5928 - val_precision: 0.5690 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4872 - auc: 0.7954 - loss: 5.0555 - precision: 0.4954 - recall: 0.4023 - val_accuracy: 0.5375 - val_auc: 0.8776 - val_loss: 4.5726 - val_precision: 0.5833 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4976 - auc: 0.8086 - loss: 4.9721 - precision: 0.5516 - recall: 0.4270 - val_accuracy: 0.5500 - val_auc: 0.8782 - val_loss: 4.5613 - val_precision: 0.5738 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4824 - auc: 0.7805 - loss: 5.0741 - precision: 0.5095 - recall: 0.3714 - val_accuracy: 0.5625 - val_auc: 0.8780 - val_loss: 4.5546 - val_precision: 0.5932 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# ✅ Fold 2 Results:
# Accuracy: 55.00%
# AUC: 0.8766
#
# 🔵 Fold 3
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 61s 455ms/step - accuracy: 0.1811 - auc: 0.4914 - loss: 6.8516 - precision: 0.1746 - recall: 0.1256 - val_accuracy: 0.1750 - val_auc: 0.4856 - val_loss: 5.8149 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.1809 - auc: 0.4865 - loss: 6.8484 - precision: 0.1471 - recall: 0.1029 - val_accuracy: 0.2500 - val_auc: 0.5282 - val_loss: 5.7383 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.1867 - auc: 0.4922 - loss: 6.7725 - precision: 0.1995 - recall: 0.1329 - val_accuracy: 0.3250 - val_auc: 0.5882 - val_loss: 5.6513 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2150 - auc: 0.5281 - loss: 6.5652 - precision: 0.2419 - recall: 0.1725 - val_accuracy: 0.4000 - val_auc: 0.6266 - val_loss: 5.5885 - val_precision: 1.0000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.2420 - auc: 0.5417 - loss: 6.5088 - precision: 0.2130 - recall: 0.1462 - val_accuracy: 0.4375 - val_auc: 0.6726 - val_loss: 5.5212 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2309 - auc: 0.5268 - loss: 6.6915 - precision: 0.2322 - recall: 0.1674 - val_accuracy: 0.4375 - val_auc: 0.6978 - val_loss: 5.4703 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.2520 - auc: 0.5497 - loss: 6.4705 - precision: 0.2298 - recall: 0.1606 - val_accuracy: 0.4500 - val_auc: 0.7267 - val_loss: 5.4136 - val_precision: 1.0000 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.2481 - auc: 0.5633 - loss: 6.3347 - precision: 0.2360 - recall: 0.1702 - val_accuracy: 0.4625 - val_auc: 0.7482 - val_loss: 5.3632 - val_precision: 1.0000 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2684 - auc: 0.5993 - loss: 6.1855 - precision: 0.2895 - recall: 0.2022 - val_accuracy: 0.4625 - val_auc: 0.7695 - val_loss: 5.3103 - val_precision: 0.9231 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.3391 - auc: 0.6232 - loss: 6.0862 - precision: 0.3647 - recall: 0.2428 - val_accuracy: 0.4875 - val_auc: 0.7861 - val_loss: 5.2627 - val_precision: 0.9474 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2960 - auc: 0.5787 - loss: 6.3157 - precision: 0.3373 - recall: 0.2542 - val_accuracy: 0.4875 - val_auc: 0.7958 - val_loss: 5.2308 - val_precision: 0.9524 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2545 - auc: 0.5789 - loss: 6.2798 - precision: 0.2437 - recall: 0.1756 - val_accuracy: 0.4875 - val_auc: 0.8057 - val_loss: 5.1919 - val_precision: 0.7857 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.3300 - auc: 0.6689 - loss: 5.8292 - precision: 0.3762 - recall: 0.2519 - val_accuracy: 0.5125 - val_auc: 0.8157 - val_loss: 5.1590 - val_precision: 0.7586 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2839 - auc: 0.6225 - loss: 6.0657 - precision: 0.3120 - recall: 0.2140 - val_accuracy: 0.5125 - val_auc: 0.8224 - val_loss: 5.1298 - val_precision: 0.7857 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3352 - auc: 0.6648 - loss: 5.8381 - precision: 0.3856 - recall: 0.2716 - val_accuracy: 0.5125 - val_auc: 0.8315 - val_loss: 5.0961 - val_precision: 0.7742 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3733 - auc: 0.6305 - loss: 5.9868 - precision: 0.3751 - recall: 0.2634 - val_accuracy: 0.5125 - val_auc: 0.8426 - val_loss: 5.0546 - val_precision: 0.7500 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3618 - auc: 0.6853 - loss: 5.7536 - precision: 0.4235 - recall: 0.2977 - val_accuracy: 0.5250 - val_auc: 0.8488 - val_loss: 5.0217 - val_precision: 0.7576 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.3574 - auc: 0.6825 - loss: 5.7619 - precision: 0.3978 - recall: 0.2713 - val_accuracy: 0.5625 - val_auc: 0.8538 - val_loss: 4.9922 - val_precision: 0.7714 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3251 - auc: 0.6327 - loss: 5.8996 - precision: 0.3643 - recall: 0.2624 - val_accuracy: 0.5500 - val_auc: 0.8575 - val_loss: 4.9682 - val_precision: 0.7692 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.3874 - auc: 0.6954 - loss: 5.6789 - precision: 0.4252 - recall: 0.2975 - val_accuracy: 0.5375 - val_auc: 0.8586 - val_loss: 4.9530 - val_precision: 0.7838 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3364 - auc: 0.6434 - loss: 5.8657 - precision: 0.3955 - recall: 0.2863 - val_accuracy: 0.5625 - val_auc: 0.8656 - val_loss: 4.9189 - val_precision: 0.8056 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.3531 - auc: 0.6712 - loss: 5.8604 - precision: 0.3988 - recall: 0.2793 - val_accuracy: 0.5750 - val_auc: 0.8700 - val_loss: 4.8926 - val_precision: 0.7838 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.3233 - auc: 0.6199 - loss: 6.0415 - precision: 0.3445 - recall: 0.2631 - val_accuracy: 0.5625 - val_auc: 0.8728 - val_loss: 4.8698 - val_precision: 0.7895 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3729 - auc: 0.6930 - loss: 5.6674 - precision: 0.4158 - recall: 0.2903 - val_accuracy: 0.6250 - val_auc: 0.8786 - val_loss: 4.8381 - val_precision: 0.7692 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3589 - auc: 0.7135 - loss: 5.5430 - precision: 0.4238 - recall: 0.2821 - val_accuracy: 0.6375 - val_auc: 0.8831 - val_loss: 4.8105 - val_precision: 0.7805 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3811 - auc: 0.6596 - loss: 5.8145 - precision: 0.3928 - recall: 0.2785 - val_accuracy: 0.6750 - val_auc: 0.8881 - val_loss: 4.7824 - val_precision: 0.7907 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4177 - auc: 0.7509 - loss: 5.2425 - precision: 0.4601 - recall: 0.3448 - val_accuracy: 0.6500 - val_auc: 0.9086 - val_loss: 4.4671 - val_precision: 0.7358 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4680 - auc: 0.7589 - loss: 5.2039 - precision: 0.4996 - recall: 0.3624 - val_accuracy: 0.6375 - val_auc: 0.9063 - val_loss: 4.4639 - val_precision: 0.7069 - val_recall: 0.5125 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4324 - auc: 0.7731 - loss: 5.0865 - precision: 0.4924 - recall: 0.3859 - val_accuracy: 0.6375 - val_auc: 0.9082 - val_loss: 4.4506 - val_precision: 0.7321 - val_recall: 0.5125 - learning_rate: 3.0000e-05
# ✅ Fold 3 Results:
# Accuracy: 63.75%
# AUC: 0.9078
#
# 🔵 Fold 4
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 62s 460ms/step - accuracy: 0.2667 - auc: 0.5555 - loss: 6.5651 - precision: 0.2578 - recall: 0.1904 - val_accuracy: 0.2250 - val_auc: 0.5279 - val_loss: 5.8019 - val_precision: 0.2500 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.1876 - auc: 0.4892 - loss: 6.7557 - precision: 0.1900 - recall: 0.1288 - val_accuracy: 0.3000 - val_auc: 0.5900 - val_loss: 5.6820 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2330 - auc: 0.5793 - loss: 6.3284 - precision: 0.2482 - recall: 0.1748 - val_accuracy: 0.3750 - val_auc: 0.6498 - val_loss: 5.6023 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2723 - auc: 0.5715 - loss: 6.4164 - precision: 0.2676 - recall: 0.2123 - val_accuracy: 0.3875 - val_auc: 0.6914 - val_loss: 5.5380 - val_precision: 0.6667 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.1804 - auc: 0.4866 - loss: 6.7571 - precision: 0.2140 - recall: 0.1468 - val_accuracy: 0.3875 - val_auc: 0.7216 - val_loss: 5.4804 - val_precision: 0.6000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.2836 - auc: 0.5733 - loss: 6.3884 - precision: 0.3013 - recall: 0.2095 - val_accuracy: 0.4125 - val_auc: 0.7468 - val_loss: 5.4242 - val_precision: 0.6667 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2456 - auc: 0.5860 - loss: 6.3864 - precision: 0.2377 - recall: 0.1695 - val_accuracy: 0.4125 - val_auc: 0.7606 - val_loss: 5.3789 - val_precision: 0.5714 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2242 - auc: 0.5685 - loss: 6.4099 - precision: 0.2378 - recall: 0.1740 - val_accuracy: 0.4375 - val_auc: 0.7745 - val_loss: 5.3336 - val_precision: 0.7273 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2772 - auc: 0.6135 - loss: 6.1811 - precision: 0.3084 - recall: 0.2051 - val_accuracy: 0.4375 - val_auc: 0.7867 - val_loss: 5.2955 - val_precision: 0.7647 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3284 - auc: 0.6317 - loss: 6.0316 - precision: 0.3879 - recall: 0.2662 - val_accuracy: 0.4250 - val_auc: 0.7958 - val_loss: 5.2557 - val_precision: 0.7143 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2681 - auc: 0.5935 - loss: 6.2417 - precision: 0.2464 - recall: 0.1664 - val_accuracy: 0.4625 - val_auc: 0.8071 - val_loss: 5.2188 - val_precision: 0.7727 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3186 - auc: 0.6480 - loss: 5.9235 - precision: 0.3343 - recall: 0.2220 - val_accuracy: 0.4625 - val_auc: 0.8160 - val_loss: 5.1825 - val_precision: 0.7600 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.2980 - auc: 0.6227 - loss: 6.0218 - precision: 0.3129 - recall: 0.2166 - val_accuracy: 0.5000 - val_auc: 0.8230 - val_loss: 5.1478 - val_precision: 0.7917 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2645 - auc: 0.5651 - loss: 6.2850 - precision: 0.2690 - recall: 0.1919 - val_accuracy: 0.5125 - val_auc: 0.8330 - val_loss: 5.1077 - val_precision: 0.8077 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.3336 - auc: 0.6449 - loss: 5.9489 - precision: 0.3302 - recall: 0.2403 - val_accuracy: 0.5375 - val_auc: 0.8418 - val_loss: 5.0690 - val_precision: 0.8077 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.2849 - auc: 0.6502 - loss: 5.8792 - precision: 0.3145 - recall: 0.2255 - val_accuracy: 0.5250 - val_auc: 0.8452 - val_loss: 5.0440 - val_precision: 0.7500 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.3731 - auc: 0.6806 - loss: 5.7973 - precision: 0.3919 - recall: 0.2858 - val_accuracy: 0.5125 - val_auc: 0.8452 - val_loss: 5.0278 - val_precision: 0.7241 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.4048 - auc: 0.7218 - loss: 5.5713 - precision: 0.4159 - recall: 0.2801 - val_accuracy: 0.5500 - val_auc: 0.8495 - val_loss: 5.0029 - val_precision: 0.7500 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4155 - auc: 0.7016 - loss: 5.6896 - precision: 0.4406 - recall: 0.3323 - val_accuracy: 0.5750 - val_auc: 0.8522 - val_loss: 4.9816 - val_precision: 0.7576 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.3591 - auc: 0.6660 - loss: 5.8324 - precision: 0.3607 - recall: 0.2579 - val_accuracy: 0.5750 - val_auc: 0.8586 - val_loss: 4.9547 - val_precision: 0.7429 - val_recall: 0.3250 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3689 - auc: 0.6930 - loss: 5.7687 - precision: 0.4045 - recall: 0.2938 - val_accuracy: 0.5750 - val_auc: 0.8601 - val_loss: 4.9374 - val_precision: 0.7297 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3828 - auc: 0.7122 - loss: 5.6177 - precision: 0.4217 - recall: 0.3046 - val_accuracy: 0.5875 - val_auc: 0.8608 - val_loss: 4.9230 - val_precision: 0.7317 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.4206 - auc: 0.7266 - loss: 5.5287 - precision: 0.4906 - recall: 0.3438 - val_accuracy: 0.5750 - val_auc: 0.8637 - val_loss: 4.9023 - val_precision: 0.7073 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.4057 - auc: 0.7232 - loss: 5.5379 - precision: 0.4447 - recall: 0.3259 - val_accuracy: 0.5625 - val_auc: 0.8663 - val_loss: 4.8838 - val_precision: 0.6977 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.3495 - auc: 0.6807 - loss: 5.7173 - precision: 0.3407 - recall: 0.2429 - val_accuracy: 0.5625 - val_auc: 0.8684 - val_loss: 4.8658 - val_precision: 0.6977 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4115 - auc: 0.7238 - loss: 5.5750 - precision: 0.4529 - recall: 0.3563 - val_accuracy: 0.5625 - val_auc: 0.8696 - val_loss: 4.8486 - val_precision: 0.7111 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4296 - auc: 0.7473 - loss: 5.3933 - precision: 0.5023 - recall: 0.3509 - val_accuracy: 0.6000 - val_auc: 0.8697 - val_loss: 4.8347 - val_precision: 0.7174 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4771 - auc: 0.7608 - loss: 5.3824 - precision: 0.5150 - recall: 0.3997 - val_accuracy: 0.6000 - val_auc: 0.8724 - val_loss: 4.8172 - val_precision: 0.7174 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.4078 - auc: 0.7262 - loss: 5.4892 - precision: 0.4798 - recall: 0.3521 - val_accuracy: 0.6000 - val_auc: 0.8742 - val_loss: 4.7978 - val_precision: 0.7391 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4061 - auc: 0.7419 - loss: 5.4679 - precision: 0.4720 - recall: 0.3666 - val_accuracy: 0.6125 - val_auc: 0.8759 - val_loss: 4.7798 - val_precision: 0.7391 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4311 - auc: 0.7442 - loss: 5.4445 - precision: 0.4684 - recall: 0.3760 - val_accuracy: 0.6125 - val_auc: 0.8769 - val_loss: 4.7658 - val_precision: 0.7447 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.4544 - auc: 0.7562 - loss: 5.3435 - precision: 0.4942 - recall: 0.3802 - val_accuracy: 0.6000 - val_auc: 0.8776 - val_loss: 4.7489 - val_precision: 0.7447 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.4649 - auc: 0.7540 - loss: 5.3522 - precision: 0.5166 - recall: 0.4041 - val_accuracy: 0.5875 - val_auc: 0.8788 - val_loss: 4.7343 - val_precision: 0.7500 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.4439 - auc: 0.7656 - loss: 5.3171 - precision: 0.4700 - recall: 0.3717 - val_accuracy: 0.5625 - val_auc: 0.8806 - val_loss: 4.7198 - val_precision: 0.7347 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4563 - auc: 0.7529 - loss: 5.2980 - precision: 0.4920 - recall: 0.3829 - val_accuracy: 0.5750 - val_auc: 0.8794 - val_loss: 4.7090 - val_precision: 0.7500 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4729 - auc: 0.7649 - loss: 5.3539 - precision: 0.5075 - recall: 0.4232 - val_accuracy: 0.6000 - val_auc: 0.8795 - val_loss: 4.6993 - val_precision: 0.7391 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4965 - auc: 0.7923 - loss: 5.1370 - precision: 0.5500 - recall: 0.4190 - val_accuracy: 0.6125 - val_auc: 0.8804 - val_loss: 4.6858 - val_precision: 0.7292 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.4021 - auc: 0.7492 - loss: 5.3157 - precision: 0.4463 - recall: 0.3524 - val_accuracy: 0.6250 - val_auc: 0.8817 - val_loss: 4.6706 - val_precision: 0.7292 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4228 - auc: 0.7506 - loss: 5.3591 - precision: 0.4978 - recall: 0.4006 - val_accuracy: 0.6250 - val_auc: 0.8813 - val_loss: 4.6635 - val_precision: 0.7391 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4740 - auc: 0.7718 - loss: 5.2136 - precision: 0.5239 - recall: 0.3750 - val_accuracy: 0.6250 - val_auc: 0.8846 - val_loss: 4.6429 - val_precision: 0.7234 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4237 - auc: 0.7504 - loss: 5.4199 - precision: 0.4622 - recall: 0.3677 - val_accuracy: 0.6250 - val_auc: 0.8843 - val_loss: 4.6339 - val_precision: 0.7234 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4702 - auc: 0.7564 - loss: 5.3497 - precision: 0.5264 - recall: 0.4280 - val_accuracy: 0.6000 - val_auc: 0.8861 - val_loss: 4.6185 - val_precision: 0.7234 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5156 - auc: 0.8135 - loss: 5.0093 - precision: 0.5756 - recall: 0.4662 - val_accuracy: 0.6125 - val_auc: 0.8888 - val_loss: 4.6007 - val_precision: 0.7083 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4895 - auc: 0.7902 - loss: 5.1211 - precision: 0.4879 - recall: 0.4107 - val_accuracy: 0.6250 - val_auc: 0.8905 - val_loss: 4.5820 - val_precision: 0.7143 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.4263 - auc: 0.7374 - loss: 5.3047 - precision: 0.4960 - recall: 0.3802 - val_accuracy: 0.6125 - val_auc: 0.8920 - val_loss: 4.5683 - val_precision: 0.6863 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.4900 - auc: 0.7953 - loss: 5.1066 - precision: 0.5726 - recall: 0.4531 - val_accuracy: 0.6250 - val_auc: 0.8925 - val_loss: 4.5530 - val_precision: 0.6923 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4924 - auc: 0.7893 - loss: 5.0800 - precision: 0.5672 - recall: 0.4193 - val_accuracy: 0.6000 - val_auc: 0.8920 - val_loss: 4.5418 - val_precision: 0.7000 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4785 - auc: 0.7979 - loss: 5.0288 - precision: 0.5083 - recall: 0.3957 - val_accuracy: 0.6125 - val_auc: 0.8929 - val_loss: 4.5316 - val_precision: 0.7143 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.5758 - auc: 0.8143 - loss: 4.9808 - precision: 0.5929 - recall: 0.4989 - val_accuracy: 0.6000 - val_auc: 0.8935 - val_loss: 4.5195 - val_precision: 0.7143 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4981 - auc: 0.7748 - loss: 5.1193 - precision: 0.5715 - recall: 0.4545 - val_accuracy: 0.6125 - val_auc: 0.8934 - val_loss: 4.5081 - val_precision: 0.7000 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# ✅ Fold 4 Results:
# Accuracy: 60.00%
# AUC: 0.8929
#
# 🔵 Fold 5
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 64s 478ms/step - accuracy: 0.2249 - auc: 0.5274 - loss: 6.6608 - precision: 0.2458 - recall: 0.1697 - val_accuracy: 0.2250 - val_auc: 0.5541 - val_loss: 5.7873 - val_precision: 0.3636 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2327 - auc: 0.5461 - loss: 6.5533 - precision: 0.2801 - recall: 0.1855 - val_accuracy: 0.3000 - val_auc: 0.5973 - val_loss: 5.6947 - val_precision: 0.4286 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.1726 - auc: 0.5182 - loss: 6.6674 - precision: 0.2042 - recall: 0.1371 - val_accuracy: 0.3875 - val_auc: 0.6410 - val_loss: 5.6114 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2416 - auc: 0.5546 - loss: 6.6301 - precision: 0.2187 - recall: 0.1492 - val_accuracy: 0.4000 - val_auc: 0.6730 - val_loss: 5.5502 - val_precision: 0.7500 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.1882 - auc: 0.4928 - loss: 6.7802 - precision: 0.1919 - recall: 0.1296 - val_accuracy: 0.4250 - val_auc: 0.6973 - val_loss: 5.5004 - val_precision: 0.7000 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2704 - auc: 0.5875 - loss: 6.2716 - precision: 0.2917 - recall: 0.1968 - val_accuracy: 0.4625 - val_auc: 0.7112 - val_loss: 5.4649 - val_precision: 0.6154 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.2689 - auc: 0.6304 - loss: 6.1354 - precision: 0.2741 - recall: 0.2033 - val_accuracy: 0.4625 - val_auc: 0.7196 - val_loss: 5.4383 - val_precision: 0.6667 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.2780 - auc: 0.6078 - loss: 6.2171 - precision: 0.2925 - recall: 0.1961 - val_accuracy: 0.4625 - val_auc: 0.7359 - val_loss: 5.3962 - val_precision: 0.6667 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.3018 - auc: 0.6150 - loss: 6.2294 - precision: 0.2651 - recall: 0.1966 - val_accuracy: 0.4750 - val_auc: 0.7534 - val_loss: 5.3535 - val_precision: 0.6190 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.3366 - auc: 0.6655 - loss: 5.9300 - precision: 0.3469 - recall: 0.2642 - val_accuracy: 0.5125 - val_auc: 0.7631 - val_loss: 5.3230 - val_precision: 0.6364 - val_recall: 0.1750 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.2934 - auc: 0.6463 - loss: 5.9378 - precision: 0.3266 - recall: 0.2251 - val_accuracy: 0.5125 - val_auc: 0.7729 - val_loss: 5.2910 - val_precision: 0.5600 - val_recall: 0.1750 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.3474 - auc: 0.6935 - loss: 5.8613 - precision: 0.3785 - recall: 0.3133 - val_accuracy: 0.5375 - val_auc: 0.7794 - val_loss: 5.2651 - val_precision: 0.5185 - val_recall: 0.1750 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.2651 - auc: 0.6207 - loss: 6.0643 - precision: 0.2635 - recall: 0.1928 - val_accuracy: 0.5375 - val_auc: 0.7804 - val_loss: 5.2529 - val_precision: 0.5517 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.3724 - auc: 0.6602 - loss: 5.9707 - precision: 0.4378 - recall: 0.3199 - val_accuracy: 0.5250 - val_auc: 0.7837 - val_loss: 5.2365 - val_precision: 0.6061 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3788 - auc: 0.7291 - loss: 5.5573 - precision: 0.4682 - recall: 0.3339 - val_accuracy: 0.5250 - val_auc: 0.7867 - val_loss: 5.2165 - val_precision: 0.6286 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.3609 - auc: 0.6833 - loss: 5.8142 - precision: 0.3809 - recall: 0.2713 - val_accuracy: 0.5000 - val_auc: 0.7901 - val_loss: 5.1999 - val_precision: 0.6389 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.3771 - auc: 0.6791 - loss: 5.8893 - precision: 0.3959 - recall: 0.3030 - val_accuracy: 0.5125 - val_auc: 0.7928 - val_loss: 5.1836 - val_precision: 0.6486 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.3826 - auc: 0.6984 - loss: 5.8378 - precision: 0.4450 - recall: 0.3322 - val_accuracy: 0.5125 - val_auc: 0.7956 - val_loss: 5.1663 - val_precision: 0.6486 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.3288 - auc: 0.6724 - loss: 5.7935 - precision: 0.3524 - recall: 0.2457 - val_accuracy: 0.5250 - val_auc: 0.8020 - val_loss: 5.1412 - val_precision: 0.6316 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.4067 - auc: 0.7074 - loss: 5.6746 - precision: 0.4432 - recall: 0.3348 - val_accuracy: 0.5500 - val_auc: 0.8048 - val_loss: 5.1185 - val_precision: 0.6316 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.4650 - auc: 0.7505 - loss: 5.5015 - precision: 0.5169 - recall: 0.3936 - val_accuracy: 0.5250 - val_auc: 0.8077 - val_loss: 5.1009 - val_precision: 0.6154 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.4455 - auc: 0.7595 - loss: 5.4522 - precision: 0.5020 - recall: 0.3939 - val_accuracy: 0.5500 - val_auc: 0.8142 - val_loss: 5.0748 - val_precision: 0.6486 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.3362 - auc: 0.6954 - loss: 5.7104 - precision: 0.3745 - recall: 0.2872 - val_accuracy: 0.5500 - val_auc: 0.8194 - val_loss: 5.0549 - val_precision: 0.6410 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4230 - auc: 0.7103 - loss: 5.7036 - precision: 0.4579 - recall: 0.3755 - val_accuracy: 0.5500 - val_auc: 0.8182 - val_loss: 5.0456 - val_precision: 0.6585 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# ✅ Fold 5 Results:
# Accuracy: 55.00%
# AUC: 0.8129
#
# === CROSS-VALIDATION RESULTS ===
# Accuracy: 0.5675 ± 0.0472
# Precision: 0.6272 ± 0.0409
# Recall: 0.5675 ± 0.0472
# F1: 0.5393 ± 0.0671
# Auc: 0.8507 ± 0.0543
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 28ms/step
# Making prediction on test image...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step
# Prediction Probabilities:
# NO Dr: 80.46%
# Moderate: 8.76%
# Proliferative_DR: 4.64%
# Mild: 4.00%
# Severe Dr: 2.14%
