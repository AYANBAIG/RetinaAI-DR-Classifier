# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, confusion_matrix, 
                           precision_score, recall_score, f1_score, 
                           accuracy_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc
import math
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
from collections import Counter

# ====== CONFIGURATION ======
class Config:
    BATCH_SIZE = 32
    IMG_SIZE = (256, 256)
    NUM_FOLDS = 5
    EPOCHS = 50
    LEARNING_RATE = 3e-5
    DROPOUT_RATE = 0.5  # Increased dropout
    SE_RATIO = 16
    BASE_DIR = '/kaggle/input/local-preprocessed-dataset/LOCAL PREPROCESSED DATASET'
    SEED = 42
    MIN_SAMPLES = 20

# ====== DATA AUGMENTATION ======
def create_augmenter():
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,  # Reduced augmentation
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.95, 1.05],  # Narrower range
        fill_mode='reflect',
        validation_split=0.2
    )

# ====== SQUEEZE-EXCITATION BLOCK ======
def se_block(input_tensor, ratio=Config.SE_RATIO):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(channels // ratio, activation='relu', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    
    return layers.Multiply()([input_tensor, se])

# ====== ENHANCED RESNET50 MODEL ======
def build_enhanced_resnet50(num_classes):
    base_model = ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=(*Config.IMG_SIZE, 3),
        pooling='avg'  # Changed from None to avg
    )
    
    # Freeze more layers
    for layer in base_model.layers[:150]:
        layer.trainable = False
    
    x = base_model.output
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    x = layers.Dense(256, activation='relu', 
                    kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=outputs)
    
    optimizer = optimizers.Adam(
        learning_rate=Config.LEARNING_RATE,
        clipnorm=1.0
    )
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')]
    )
    
    return model

# ====== CUSTOM DATA GENERATOR ======
class AdvancedDataGenerator(Sequence):
    def __init__(self, filepaths, labels, datagen, batch_size=32, img_size=(256,256), shuffle=True):
        self.filepaths = filepaths
        self.labels = labels
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.filepaths) / self.batch_size)

    def __getitem__(self, index):
        batch_files = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        images = []
        for filepath in batch_files:
            img = image.load_img(filepath, target_size=self.img_size)
            img_array = image.img_to_array(img)
            img_array = self.datagen.standardize(img_array)
            images.append(img_array)
            
        return np.array(images), tf.keras.utils.to_categorical(batch_labels, num_classes=len(set(self.labels)))

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.filepaths))
            np.random.shuffle(indices)
            self.filepaths = [self.filepaths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# ====== TRAINING PIPELINE ======
def run_training():
    # Initialize data
    datagen = create_augmenter()
    train_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=Config.SEED
    )
    
    # Data integrity checks
    print("\n=== DATA VALIDATION ===")
    print("Class distribution in training:", Counter(train_gen.labels))
    
    val_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=Config.SEED
    )
    print("Class distribution in validation:", Counter(val_gen.labels))
    
    # Verify no overlap
    train_files = set(train_gen.filepaths)
    val_files = set(val_gen.filepaths)
    print(f"Number of overlapping files: {len(train_files & val_files)}")
    
    class_indices = train_gen.class_indices
    X = train_gen.filepaths
    y = train_gen.labels
    
    # Cross-validation setup
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    fold_no = 1
    history_list = []
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1': [],
        'auc': []
    }

    for train_idx, val_idx in kf.split(X, y):
        print(f"\n🔵 Fold {fold_no}")
        
        # Create generators
        simple_datagen = ImageDataGenerator(rescale=1./255)
        train_data = AdvancedDataGenerator(
            [X[i] for i in train_idx],
            [y[i] for i in train_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE
        )
        val_data = AdvancedDataGenerator(
            [X[i] for i in val_idx],
            [y[i] for i in val_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE,
            shuffle=False
        )
        
        # Build model
        model = build_enhanced_resnet50(len(class_indices))
        
        # Callbacks
        callbacks_list = [
            callbacks.EarlyStopping(
                monitor='val_auc',
                patience=15,
                mode='max',
                baseline=0.85,
                restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=1e-6,
                cooldown=2
            ),
            callbacks.ModelCheckpoint(
                f'resnet50_fold_{fold_no}.keras',
                monitor='val_auc',
                save_best_only=True,
                mode='max'
            )
        ]
        
        # Train
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=Config.EPOCHS,
            callbacks=callbacks_list,
            verbose=1
        )
        history_list.append(history)
        
        # Evaluate
        val_preds = model.predict(val_data, verbose=0)
        val_preds_labels = np.argmax(val_preds, axis=1)
        val_true_labels = val_data.labels
        
        # Store metrics
        metrics['accuracy'].append(accuracy_score(val_true_labels, val_preds_labels))
        metrics['precision'].append(precision_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['recall'].append(recall_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['f1'].append(f1_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['auc'].append(np.mean(history.history['val_auc'][-5:]))
        
        print(f"✅ Fold {fold_no} Results:")
        print(f"Accuracy: {metrics['accuracy'][-1]*100:.2f}%")
        print(f"AUC: {metrics['auc'][-1]:.4f}")
        
        fold_no += 1
        tf.keras.backend.clear_session()
        gc.collect()
    
    # Final results
    print("\n=== CROSS-VALIDATION RESULTS ===")
    for metric, values in metrics.items():
        print(f"{metric.capitalize()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
    
    return history_list, metrics, class_indices, X, y  # Return X and y for plotting

# ====== VISUALIZATION ======
def plot_results(history_list, metrics, class_indices, X, y):
    # Training curves
    plt.figure(figsize=(20, 10))
    
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_accuracy'], alpha=0.3, color='orange')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['loss'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_loss'], alpha=0.3, color='orange')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
    # Confusion matrix for best fold
    best_fold = np.argmax(metrics['auc']) + 1
    model = tf.keras.models.load_model(f'resnet50_fold_{best_fold}.keras')
    
    # Get validation data for best fold
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    splits = list(kf.split(X, y))
    _, val_idx = splits[best_fold-1]
    
    val_data = AdvancedDataGenerator(
        [X[i] for i in val_idx],
        [y[i] for i in val_idx],
        ImageDataGenerator(rescale=1./255),
        Config.BATCH_SIZE,
        Config.IMG_SIZE,
        shuffle=False
    )
    
    val_preds = model.predict(val_data)
    val_preds_labels = np.argmax(val_preds, axis=1)
    
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(val_data.labels, val_preds_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_indices.keys(),
                yticklabels=class_indices.keys())
    plt.title(f'ResNet50 Confusion Matrix (Fold {best_fold})')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# ====== PREDICTION UTILITIES ======
class ResNetPredictor:
    def __init__(self, model_path, class_indices):
        self.model = tf.keras.models.load_model(model_path)
        self.class_indices = class_indices
        self.img_size = Config.IMG_SIZE
        
    def predict_image(self, image_path):
        """Make prediction with visualization."""
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Image not found: {image_path}")
            
        img = image.load_img(image_path, target_size=self.img_size)
        img_array = image.img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        pred = self.model.predict(img_array)[0]
        sorted_idx = np.argsort(pred)[::-1]
        
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Input Image')
        
        plt.subplot(1, 2, 2)
        colors = plt.cm.rainbow(np.linspace(0, 1, len(self.class_indices)))
        for i, idx in enumerate(sorted_idx[:3]):
            plt.barh(i, pred[idx]*100, color=colors[idx])
            plt.text(pred[idx]*100 + 1, i, 
                    f"{list(self.class_indices.keys())[idx]}: {pred[idx]*100:.2f}%",
                    va='center')
        plt.yticks([])
        plt.xlabel('Confidence (%)')
        plt.title('Top Predictions')
        plt.xlim(0, 100)
        plt.tight_layout()
        plt.show()
        
        return {list(self.class_indices.keys())[i]: float(pred[i]) for i in sorted_idx}

# ====== MAIN EXECUTION ======
if __name__ == "__main__":
    # Run training
    history_list, metrics, class_indices, X, y = run_training()
    
    # Visualize results
    plot_results(history_list, metrics, class_indices, X, y)
    
    # Example prediction
    predictor = ResNetPredictor('resnet50_fold_1.keras', class_indices)
    test_image = os.path.join(Config.BASE_DIR, 'NO Dr/005b95c28852.png')
    
    if os.path.exists(test_image):
        print("\nMaking prediction on test image...")
        predictions = predictor.predict_image(test_image)
        print("\nPrediction Probabilities:")
        for cls, prob in predictions.items():
            print(f"{cls}: {prob*100:.2f}%")
    else:
        print(f"\nTest image not found at: {test_image}")
        print("Please provide a valid image path for prediction.")
# Out:
# Found 400 images belonging to 5 classes.
#
# === DATA VALIDATION ===
# Class distribution in training: Counter({0: 80, 1: 80, 2: 80, 3: 80, 4: 80})
# Found 100 images belonging to 5 classes.
# Class distribution in validation: Counter({0: 20, 1: 20, 2: 20, 3: 20, 4: 20})
# Number of overlapping files: 0
#
# 🔵 Fold 1
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.2403 - auc: 0.5760 - loss: 6.8872 - precision: 0.2561 - recall: 0.1861 - val_accuracy: 0.2750 - val_auc: 0.5007 - val_loss: 6.5455 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.3621 - auc: 0.6659 - loss: 6.4896 - precision: 0.3921 - recall: 0.2943 - val_accuracy: 0.2750 - val_auc: 0.5051 - val_loss: 6.4940 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.4412 - auc: 0.7738 - loss: 6.0448 - precision: 0.5099 - recall: 0.3966 - val_accuracy: 0.2750 - val_auc: 0.5064 - val_loss: 6.4484 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 
50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9792 - auc: 0.9985 - loss: 4.4166 - precision: 0.9810 - recall: 0.9693 - val_accuracy: 0.5875 - val_auc: 0.8604 - val_loss: 5.3801 - val_precision: 0.6923 - val_recall: 0.4500 - learning_rate: 3.0000e-05
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9813 - auc: 0.9997 - loss: 4.3598 - precision: 0.9813 - recall: 0.9813 - val_accuracy: 0.5875 - val_auc: 0.8609 - val_loss: 5.3612 - val_precision: 0.7451 - val_recall: 0.4750 - learning_rate: 3.0000e-05
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9783 - auc: 0.9996 - loss: 4.3318 - precision: 0.9821 - recall: 0.9749 - val_accuracy: 0.5875 - val_auc: 0.8596 - val_loss: 5.3639 - val_precision: 0.6842 - val_recall: 0.4875 - learning_rate: 3.0000e-05
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9944 - auc: 0.9999 - loss: 4.2929 - precision: 0.9944 - recall: 0.9944 - val_accuracy: 0.6000 - val_auc: 0.8656 - val_loss: 5.3397 - val_precision: 0.6833 - val_recall: 0.5125 - learning_rate: 3.0000e-05
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9814 - auc: 0.9998 - loss: 4.2665 - precision: 0.9826 - recall: 0.9814 - val_accuracy: 0.6250 - val_auc: 0.8692 - val_loss: 5.3152 - val_precision: 0.6452 - val_recall: 0.5000 - learning_rate: 3.0000e-05
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9923 - auc: 0.9998 - loss: 4.2276 - precision: 0.9923 - recall: 0.9923 - val_accuracy: 0.6000 - val_auc: 0.8649 - val_loss: 5.3373 - val_precision: 0.6825 - val_recall: 0.5375 - learning_rate: 3.0000e-05
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9951 - auc: 1.0000 - loss: 4.1805 - precision: 0.9951 - recall: 0.9951 - val_accuracy: 0.5875 - val_auc: 0.8651 - val_loss: 5.3368 - val_precision: 0.6567 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9920 - auc: 0.9999 - loss: 4.1530 - precision: 0.9941 - recall: 0.9920 - val_accuracy: 0.6000 - val_auc: 0.8742 - val_loss: 5.2610 - val_precision: 0.6618 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 4.1139 - precision: 0.9979 - recall: 0.9979 - val_accuracy: 0.6000 - val_auc: 0.8760 - val_loss: 5.2494 - val_precision: 0.6338 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9923 - auc: 0.9998 - loss: 4.0864 - precision: 0.9923 - recall: 0.9917 - val_accuracy: 0.5500 - val_auc: 0.8726 - val_loss: 5.2345 - val_precision: 0.6324 - val_recall: 0.5375 - learning_rate: 3.0000e-05
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 4.0310 - precision: 0.9957 - recall: 0.9957 - val_accuracy: 0.6125 - val_auc: 0.8712 - val_loss: 5.2057 - val_precision: 0.6286 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.9905 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.8719 - val_loss: 5.1917 - val_precision: 0.6081 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.9442 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.5750 - val_auc: 0.8705 - val_loss: 5.1675 - val_precision: 0.6111 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.9153 - precision: 1.0000 - recall: 0.9984 - val_accuracy: 0.5875 - val_auc: 0.8683 - val_loss: 5.1357 - val_precision: 0.6338 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9885 - auc: 0.9999 - loss: 3.8872 - precision: 0.9885 - recall: 0.9885 - val_accuracy: 0.5875 - val_auc: 0.8623 - val_loss: 5.1854 - val_precision: 0.5972 - val_recall: 0.5375 - learning_rate: 3.0000e-05
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.8329 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.5625 - val_auc: 0.8502 - val_loss: 5.2381 - val_precision: 0.6056 - val_recall: 0.5375 - learning_rate: 3.0000e-05
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9960 - auc: 1.0000 - loss: 3.8032 - precision: 0.9960 - recall: 0.9960 - val_accuracy: 0.5500 - val_auc: 0.8466 - val_loss: 5.2778 - val_precision: 0.5867 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - accuracy: 0.9945 - auc: 1.0000 - loss: 3.7643 - precision: 0.9945 - recall: 0.9945 - val_accuracy: 0.6000 - val_auc: 0.8558 - val_loss: 5.2113 - val_precision: 0.6164 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.7295 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6250 - val_auc: 0.8557 - val_loss: 5.1744 - val_precision: 0.6400 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.6799 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.8422 - val_loss: 5.2187 - val_precision: 0.6184 - val_recall: 0.5875 - learning_rate: 3.0000e-05
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.6389 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6250 - val_auc: 0.8388 - val_loss: 5.2095 - val_precision: 0.6267 - val_recall: 0.5875 - learning_rate: 3.0000e-05
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.6013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.5875 - val_auc: 0.8427 - val_loss: 5.2259 - val_precision: 0.6053 - val_recall: 0.5750 - learning_rate: 3.0000e-05
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.5652 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.5875 - val_auc: 0.8455 - val_loss: 5.1981 - val_precision: 0.6026 - val_recall: 0.5875 - learning_rate: 6.0000e-06
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9914 - auc: 0.9999 - loss: 3.5721 - precision: 0.9914 - recall: 0.9914 - val_accuracy: 0.6000 - val_auc: 0.8505 - val_loss: 5.1558 - val_precision: 0.6104 - val_recall: 0.5875 - learning_rate: 6.0000e-06
# ✅ Fold 1 Results:
# Accuracy: 60.00%
# AUC: 0.8439
#
# 🔵 Fold 2
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.2200 - auc: 0.5416 - loss: 7.2121 - precision: 0.2283 - recall: 0.1726 - val_accuracy: 0.2000 - val_auc: 0.5274 - val_loss: 6.4363 - val_precision: 0.1897 - val_recall: 0.1375 - learning_rate: 3.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.3512 - auc: 0.6772 - loss: 6.4121 - precision: 0.4098 - recall: 0.2785 - val_accuracy: 0.2000 - val_auc: 0.5343 - val_loss: 6.3821 - val_precision: 0.1818 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.4163 - auc: 0.7528 - loss: 6.1283 - precision: 0.4701 - recall: 0.3547 - val_accuracy: 0.2000 - val_auc: 0.5411 - val_loss: 6.3482 - val_precision: 0.1750 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.4873 - auc: 0.7918 - loss: 5.9717 - precision: 0.5401 - recall: 0.4235 - val_accuracy: 0.2000 - val_auc: 0.5558 - val_loss: 6.3016 - val_precision: 0.2333 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.5331 - auc: 0.8056 - loss: 6.0269 - precision: 0.5589 - recall: 0.4690 - val_accuracy: 0.2125 - val_auc: 0.5650 - val_loss: 6.2536 - val_precision: 0.2500 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.5787 - auc: 0.8449 - loss: 5.7631 - precision: 0.6233 - recall: 0.5496 - val_accuracy: 0.2375 - val_auc: 0.5723 - val_loss: 6.2126 - val_precision: 0.0909 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.5923 - auc: 0.8645 - loss: 5.6248 - precision: 0.6603 - recall: 0.5700 - val_accuracy: 0.2375 - val_auc: 0.5875 - val_loss: 6.1629 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.5934 - auc: 0.8796 - loss: 5.5525 - precision: 0.6560 - recall: 0.5467 - val_accuracy: 0.2500 - val_auc: 0.6005 - val_loss: 6.1194 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 
50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9930 - auc: 1.0000 - loss: 4.2923 - precision: 0.9988 - recall: 0.9930 - val_accuracy: 0.5875 - val_auc: 0.8518 - val_loss: 5.5764 - val_precision: 0.6522 - val_recall: 0.5625 - learning_rate: 6.0000e-06
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.9835 - auc: 0.9998 - loss: 4.3037 - precision: 0.9834 - recall: 0.9780 - val_accuracy: 0.5875 - val_auc: 0.8510 - val_loss: 5.5952 - val_precision: 0.6618 - val_recall: 0.5625 - learning_rate: 6.0000e-06
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.9857 - auc: 0.9998 - loss: 4.2938 - precision: 0.9857 - recall: 0.9845 - val_accuracy: 0.6000 - val_auc: 0.8550 - val_loss: 5.6018 - val_precision: 0.6618 - val_recall: 0.5625 - learning_rate: 6.0000e-06
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2680 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.8573 - val_loss: 5.6309 - val_precision: 0.6479 - val_recall: 0.5750 - learning_rate: 6.0000e-06
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9821 - auc: 0.9998 - loss: 4.2759 - precision: 0.9821 - recall: 0.9821 - val_accuracy: 0.6125 - val_auc: 0.8577 - val_loss: 5.6730 - val_precision: 0.6479 - val_recall: 0.5750 - learning_rate: 6.0000e-06
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9914 - auc: 0.9996 - loss: 4.2753 - precision: 0.9914 - recall: 0.9914 - val_accuracy: 0.6125 - val_auc: 0.8573 - val_loss: 5.6998 - val_precision: 0.6438 - val_recall: 0.5875 - learning_rate: 6.0000e-06
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.9914 - auc: 0.9999 - loss: 4.2587 - precision: 0.9914 - recall: 0.9914 - val_accuracy: 0.6000 - val_auc: 0.8554 - val_loss: 5.7070 - val_precision: 0.6133 - val_recall: 0.5750 - learning_rate: 6.0000e-06
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.9967 - auc: 1.0000 - loss: 4.2441 - precision: 0.9967 - recall: 0.9910 - val_accuracy: 0.6000 - val_auc: 0.8563 - val_loss: 5.7016 - val_precision: 0.6164 - val_recall: 0.5625 - learning_rate: 6.0000e-06
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 4.2283 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.6000 - val_auc: 0.8567 - val_loss: 5.7102 - val_precision: 0.6164 - val_recall: 0.5625 - learning_rate: 6.0000e-06
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 4.2199 - precision: 0.9979 - recall: 0.9979 - val_accuracy: 0.6000 - val_auc: 0.8578 - val_loss: 5.7215 - val_precision: 0.6164 - val_recall: 0.5625 - learning_rate: 1.2000e-06
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2123 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6125 - val_auc: 0.8582 - val_loss: 5.7350 - val_precision: 0.6250 - val_recall: 0.5625 - learning_rate: 1.2000e-06
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2158 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.8594 - val_loss: 5.7460 - val_precision: 0.6250 - val_recall: 0.5625 - learning_rate: 1.2000e-06
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.2076 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.6000 - val_auc: 0.8590 - val_loss: 5.7587 - val_precision: 0.6250 - val_recall: 0.5625 - learning_rate: 1.2000e-06
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9908 - auc: 0.9999 - loss: 4.2228 - precision: 0.9908 - recall: 0.9908 - val_accuracy: 0.6000 - val_auc: 0.8596 - val_loss: 5.7666 - val_precision: 0.6197 - val_recall: 0.5500 - learning_rate: 1.2000e-06
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9868 - auc: 0.9997 - loss: 4.2371 - precision: 0.9868 - recall: 0.9834 - val_accuracy: 0.6125 - val_auc: 0.8597 - val_loss: 5.7813 - val_precision: 0.6081 - val_recall: 0.5625 - learning_rate: 1.2000e-06
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 4.2178 - precision: 0.9994 - recall: 0.9931 - val_accuracy: 0.6125 - val_auc: 0.8555 - val_loss: 5.7942 - val_precision: 0.6133 - val_recall: 0.5750 - learning_rate: 1.2000e-06
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9942 - auc: 1.0000 - loss: 4.2092 - precision: 0.9942 - recall: 0.9942 - val_accuracy: 0.6125 - val_auc: 0.8565 - val_loss: 5.7994 - val_precision: 0.6184 - val_recall: 0.5875 - learning_rate: 1.2000e-06
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9966 - auc: 1.0000 - loss: 4.2072 - precision: 0.9966 - recall: 0.9966 - val_accuracy: 0.6125 - val_auc: 0.8562 - val_loss: 5.8031 - val_precision: 0.6133 - val_recall: 0.5750 - learning_rate: 1.2000e-06
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9962 - auc: 1.0000 - loss: 4.2085 - precision: 0.9983 - recall: 0.9950 - val_accuracy: 0.6125 - val_auc: 0.8571 - val_loss: 5.8141 - val_precision: 0.6216 - val_recall: 0.5750 - learning_rate: 1.0000e-06
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9851 - auc: 0.9999 - loss: 4.2229 - precision: 0.9851 - recall: 0.9851 - val_accuracy: 0.6125 - val_auc: 0.8565 - val_loss: 5.8302 - val_precision: 0.6267 - val_recall: 0.5875 - learning_rate: 1.0000e-06
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.1959 - precision: 1.0000 - recall: 0.9988 - val_accuracy: 0.6125 - val_auc: 0.8555 - val_loss: 5.8390 - val_precision: 0.6267 - val_recall: 0.5875 - learning_rate: 1.0000e-06
# ✅ Fold 2 Results:
# Accuracy: 61.25%
# AUC: 0.8564
#
# 🔵 Fold 3
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.2377 - auc: 0.5345 - loss: 7.1067 - precision: 0.2510 - recall: 0.1709 - val_accuracy: 0.1125 - val_auc: 0.5160 - val_loss: 6.4194 - val_precision: 0.2143 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.3337 - auc: 0.6294 - loss: 6.7370 - precision: 0.3665 - recall: 0.2907 - val_accuracy: 0.1250 - val_auc: 0.5265 - val_loss: 6.3622 - val_precision: 0.2500 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.3596 - auc: 0.6780 - loss: 6.4841 - precision: 0.4079 - recall: 0.3195 - val_accuracy: 0.1625 - val_auc: 0.5319 - val_loss: 6.3242 - val_precision: 0.2000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.4664 - auc: 0.7757 - loss: 6.1221 - precision: 0.5268 - recall: 0.4189 - val_accuracy: 0.1750 - val_auc: 0.5411 - val_loss: 6.3002 - val_precision: 0.2222 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.5057 - auc: 0.8144 - loss: 5.9099 - precision: 0.5401 - recall: 0.4350 - val_accuracy: 0.1875 - val_auc: 0.5462 - val_loss: 6.2700 - val_precision: 0.1250 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.5495 - auc: 0.8445 - loss: 5.7387 - precision: 0.5946 - recall: 0.4867 - val_accuracy: 0.1875 - val_auc: 0.5594 - val_loss: 6.2357 - val_precision: 0.1250 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.6710 - auc: 0.8923 - loss: 5.4999 - precision: 0.7101 - recall: 0.5945 - val_accuracy: 0.1875 - val_auc: 0.5746 - val_loss: 6.2058 - val_precision: 0.3000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.6265 - auc: 0.8699 - loss: 5.6575 - precision: 0.6638 - recall: 0.5625 - val_accuracy: 0.2000 - val_auc: 0.5882 - val_loss: 6.1713 - val_precision: 0.2727 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.7126 - auc: 0.9249 - loss: 5.2931 - precision: 0.7646 - recall: 0.6646 - val_accuracy: 0.1875 - val_auc: 0.6058 - val_loss: 6.1266 - val_precision: 0.3000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.7617 - auc: 0.9533 - loss: 5.1138 - precision: 0.8104 - recall: 0.7396 - val_accuracy: 0.2250 - val_auc: 0.6273 - val_loss: 6.0817 - val_precision: 0.3000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━
50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9270 - auc: 0.9955 - loss: 4.6115 - precision: 0.9276 - recall: 0.9178 - val_accuracy: 0.6250 - val_auc: 0.8617 - val_loss: 5.4917 - val_precision: 0.6984 - val_recall: 0.5500 - learning_rate: 3.0000e-05
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9527 - auc: 0.9982 - loss: 4.5349 - precision: 0.9530 - recall: 0.9463 - val_accuracy: 0.6125 - val_auc: 0.8530 - val_loss: 5.5300 - val_precision: 0.6667 - val_recall: 0.5750 - learning_rate: 3.0000e-05
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9621 - auc: 0.9986 - loss: 4.5111 - precision: 0.9691 - recall: 0.9547 - val_accuracy: 0.6250 - val_auc: 0.8537 - val_loss: 5.5161 - val_precision: 0.6716 - val_recall: 0.5625 - learning_rate: 3.0000e-05
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9613 - auc: 0.9982 - loss: 4.4838 - precision: 0.9744 - recall: 0.9491 - val_accuracy: 0.6375 - val_auc: 0.8645 - val_loss: 5.4855 - val_precision: 0.6761 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9355 - auc: 0.9963 - loss: 4.5026 - precision: 0.9429 - recall: 0.9258 - val_accuracy: 0.6250 - val_auc: 0.8755 - val_loss: 5.4352 - val_precision: 0.7121 - val_recall: 0.5875 - learning_rate: 3.0000e-05
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9746 - auc: 0.9987 - loss: 4.4075 - precision: 0.9808 - recall: 0.9639 - val_accuracy: 0.6375 - val_auc: 0.8765 - val_loss: 5.4475 - val_precision: 0.6486 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9837 - auc: 0.9998 - loss: 4.3637 - precision: 0.9835 - recall: 0.9726 - val_accuracy: 0.6250 - val_auc: 0.8556 - val_loss: 5.5584 - val_precision: 0.6486 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9758 - auc: 0.9988 - loss: 4.3736 - precision: 0.9842 - recall: 0.9758 - val_accuracy: 0.6500 - val_auc: 0.8529 - val_loss: 5.6731 - val_precision: 0.6486 - val_recall: 0.6000 - learning_rate: 3.0000e-05
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.9799 - auc: 0.9994 - loss: 4.3226 - precision: 0.9855 - recall: 0.9799 - val_accuracy: 0.6875 - val_auc: 0.8647 - val_loss: 5.5222 - val_precision: 0.6800 - val_recall: 0.6375 - learning_rate: 3.0000e-05
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.9707 - auc: 0.9995 - loss: 4.2923 - precision: 0.9772 - recall: 0.9707 - val_accuracy: 0.6625 - val_auc: 0.8537 - val_loss: 5.6730 - val_precision: 0.6753 - val_recall: 0.6500 - learning_rate: 3.0000e-05
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - accuracy: 0.9935 - auc: 1.0000 - loss: 4.2383 - precision: 0.9935 - recall: 0.9935 - val_accuracy: 0.6750 - val_auc: 0.8629 - val_loss: 5.6119 - val_precision: 0.6923 - val_recall: 0.6750 - learning_rate: 3.0000e-05
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9764 - auc: 0.9995 - loss: 4.2226 - precision: 0.9878 - recall: 0.9764 - val_accuracy: 0.6500 - val_auc: 0.8564 - val_loss: 5.7403 - val_precision: 0.6753 - val_recall: 0.6500 - learning_rate: 3.0000e-05
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - accuracy: 0.9800 - auc: 0.9997 - loss: 4.1825 - precision: 0.9798 - recall: 0.9699 - val_accuracy: 0.6750 - val_auc: 0.8707 - val_loss: 5.5719 - val_precision: 0.6883 - val_recall: 0.6625 - learning_rate: 3.0000e-05
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.9872 - auc: 0.9999 - loss: 4.1401 - precision: 0.9872 - recall: 0.9872 - val_accuracy: 0.6750 - val_auc: 0.8746 - val_loss: 5.4591 - val_precision: 0.6883 - val_recall: 0.6625 - learning_rate: 6.0000e-06
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9840 - auc: 0.9999 - loss: 4.1396 - precision: 0.9840 - recall: 0.9823 - val_accuracy: 0.6875 - val_auc: 0.8770 - val_loss: 5.4298 - val_precision: 0.7297 - val_recall: 0.6750 - learning_rate: 6.0000e-06
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.1091 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7000 - val_auc: 0.8788 - val_loss: 5.4452 - val_precision: 0.7179 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0948 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7000 - val_auc: 0.8799 - val_loss: 5.4427 - val_precision: 0.7179 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 4.0910 - precision: 0.9971 - recall: 0.9913 - val_accuracy: 0.7000 - val_auc: 0.8814 - val_loss: 5.4200 - val_precision: 0.7179 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0764 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7125 - val_auc: 0.8820 - val_loss: 5.4245 - val_precision: 0.7273 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 4.0737 - precision: 0.9979 - recall: 0.9979 - val_accuracy: 0.7250 - val_auc: 0.8824 - val_loss: 5.4018 - val_precision: 0.7467 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 4.0817 - precision: 0.9979 - recall: 0.9835 - val_accuracy: 0.7500 - val_auc: 0.8875 - val_loss: 5.3990 - val_precision: 0.7568 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.9988 - auc: 1.0000 - loss: 4.0567 - precision: 0.9988 - recall: 0.9988 - val_accuracy: 0.7750 - val_auc: 0.8889 - val_loss: 5.3675 - val_precision: 0.7600 - val_recall: 0.7125 - learning_rate: 6.0000e-06
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.9984 - auc: 1.0000 - loss: 4.0449 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.7625 - val_auc: 0.8847 - val_loss: 5.3674 - val_precision: 0.7632 - val_recall: 0.7250 - learning_rate: 6.0000e-06
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0378 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7375 - val_auc: 0.8930 - val_loss: 5.3416 - val_precision: 0.7500 - val_recall: 0.7125 - learning_rate: 6.0000e-06
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 4.0310 - precision: 0.9994 - recall: 0.9994 - val_accuracy: 0.7375 - val_auc: 0.8928 - val_loss: 5.3243 - val_precision: 0.7368 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 4.0167 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7250 - val_auc: 0.8972 - val_loss: 5.3201 - val_precision: 0.7368 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 4.0236 - precision: 0.9957 - recall: 0.9957 - val_accuracy: 0.7250 - val_auc: 0.8978 - val_loss: 5.2958 - val_precision: 0.7368 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9957 - auc: 1.0000 - loss: 4.0071 - precision: 0.9957 - recall: 0.9957 - val_accuracy: 0.7250 - val_auc: 0.8995 - val_loss: 5.2665 - val_precision: 0.7368 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9991 - auc: 1.0000 - loss: 3.9933 - precision: 0.9991 - recall: 0.9991 - val_accuracy: 0.7375 - val_auc: 0.9000 - val_loss: 5.2556 - val_precision: 0.7368 - val_recall: 0.7000 - learning_rate: 6.0000e-06
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.9829 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7250 - val_auc: 0.8994 - val_loss: 5.2491 - val_precision: 0.7403 - val_recall: 0.7125 - learning_rate: 6.0000e-06
# ✅ Fold 3 Results:
# Accuracy: 73.75%
# AUC: 0.8988
#
# 🔵 Fold 4
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.1936 - auc: 0.5226 - loss: 7.1735 - precision: 0.2004 - recall: 0.1423 - val_accuracy: 0.1500 - val_auc: 0.4457 - val_loss: 6.5279 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.3730 - auc: 0.6568 - loss: 6.5705 - precision: 0.4242 - recall: 0.2969 - val_accuracy: 0.1500 - val_auc: 0.4569 - val_loss: 6.4656 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.4308 - auc: 0.7511 - loss: 6.1965 - precision: 0.4764 - recall: 0.3457 - val_accuracy: 0.1500 - val_auc: 0.4668 - val_loss: 6.4065 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.4984 - auc: 0.7883 - loss: 5.9970 - precision: 0.5685 - recall: 0.4325 - val_accuracy: 0.1500 - val_auc: 0.4782 - val_loss: 6.3503 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.5119 - auc: 0.8276 - loss: 5.8217 - precision: 0.5618 - recall: 0.4428 - val_accuracy: 0.1625 - val_auc: 0.4919 - val_loss: 6.2876 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.6434 - auc: 0.8919 - loss: 5.5240 - precision: 0.6994 - recall: 0.5768 - val_accuracy: 0.1625 - val_auc: 0.5249 - val_loss: 6.2280 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.6528 - auc: 0.8967 - loss: 5.4821 - precision: 0.7058 - recall: 0.5967 - val_accuracy: 0.1875 - val_auc: 0.5194 - val_loss: 6.1873 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.6119 - auc: 0.9061 - loss: 5.4413 - precision: 0.6580 - recall: 0.5658 - val_accuracy: 0.3250 - val_auc: 0.5490 - val_loss: 6.1510 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.7507 - auc: 0.9414 - loss: 5.2026 - precision: 0.8090 - recall: 0.6792 - val_accuracy: 0.2750 - val_auc: 0.5934 - val_loss: 6.1111 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.6913 - auc: 0.9208 - loss: 5.3201 - precision: 0.7717 - recall: 0.6255 - val_accuracy: 0.2500 - val_auc: 0.6185 - val_loss: 6.0811 - val_precision: 1.0000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.7241 - auc: 0.9380 - loss: 5.2097 - precision: 0.7630 - recall: 0.6856 - val_accuracy: 0.2375 - val_auc: 0.6328 - val_loss: 6.0703 - val_precision: 0.8462 - val_recall: 0.1375 - learning_rate: 3.0000e-05
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.7734 - auc: 0.9550 - loss: 5.1003 - precision: 0.8134 - recall: 0.7313 - val_accuracy: 0.2375 - val_auc: 0.6431 - val_loss: 6.0757 - val_precision: 0.7143 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.8329 - auc: 0.9719 - loss: 4.9625 - precision: 0.8514 - recall: 0.7941 - val_accuracy: 0.2375 - val_auc: 0.6537 - val_loss: 6.0855 - val_precision: 0.6154 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.8075 - auc: 0.9678 - loss: 4.9901 - precision: 0.8440 - recall: 0.7847 - val_accuracy: 0.2375 - val_auc: 0.6654 - val_loss: 6.0614 - val_precision: 0.5517 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.8515 - auc: 0.9800 - loss: 4.8769 - precision: 0.8946 - recall: 0.8142 - val_accuracy: 0.2375 - val_auc: 0.6718 - val_loss: 6.0602 - val_precision: 0.4444 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.8809 - auc: 0.9803 - loss: 4.8540 - precision: 0.9179 - recall: 0.8471 - val_accuracy: 0.2500 - val_auc: 0.6826 - val_loss: 6.0173 - val_precision: 0.4722 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.8617 - auc: 0.9840 - loss: 4.8195 - precision: 0.8949 - recall: 0.8337 - val_accuracy: 0.2875 - val_auc: 0.7020 - val_loss: 5.9585 - val_precision: 0.5312 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.8538 - auc: 0.9785 - loss: 4.8615 - precision: 0.8789 - recall: 0.8318 - val_accuracy: 0.3750 - val_auc: 0.7256 - val_loss: 5.9059 - val_precision: 0.5625 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9204 - auc: 0.9936 - loss: 4.6714 - precision: 0.9396 - recall: 0.8913 - val_accuracy: 0.4750 - val_auc: 0.7547 - val_loss: 5.8384 - val_precision: 0.6053 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.8992 - auc: 0.9867 - loss: 4.7502 - precision: 0.8978 - recall: 0.8697 - val_accuracy: 0.4875 - val_auc: 0.7725 - val_loss: 5.7785 - val_precision: 0.7333 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9443 - auc: 0.9962 - loss: 4.5991 - precision: 0.9542 - recall: 0.9243 - val_accuracy: 0.5375 - val_auc: 0.7838 - val_loss: 5.7584 - val_precision: 0.6731 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - accuracy: 0.9340 - auc: 0.9918 - loss: 4.6510 - precision: 0.9592 - recall: 0.9100 - val_accuracy: 0.5750 - val_auc: 0.7775 - val_loss: 5.8097 - val_precision: 0.6379 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 4 Results:
# Accuracy: 53.75%
# AUC: 0.7628
#
# 🔵 Fold 5
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.2065 - auc: 0.5111 - loss: 7.2400 - precision: 0.2035 - recall: 0.1421 - val_accuracy: 0.2125 - val_auc: 0.5131 - val_loss: 6.3191 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.3591 - auc: 0.6783 - loss: 6.4540 - precision: 0.4202 - recall: 0.3035 - val_accuracy: 0.2000 - val_auc: 0.5233 - val_loss: 6.2780 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.4059 - auc: 0.7126 - loss: 6.3218 - precision: 0.4500 - recall: 0.3454 - val_accuracy: 0.1875 - val_auc: 0.5382 - val_loss: 6.2453 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.4897 - auc: 0.7885 - loss: 6.0801 - precision: 0.5334 - recall: 0.4451 - val_accuracy: 0.2000 - val_auc: 0.5442 - val_loss: 6.2278 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - accuracy: 0.5801 - auc: 0.8459 - loss: 5.7595 - precision: 0.6446 - recall: 0.5057 - val_accuracy: 0.2125 - val_auc: 0.5522 - val_loss: 6.2123 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.5664 - auc: 0.8482 - loss: 5.8002 - precision: 0.6103 - recall: 0.5204 - val_accuracy: 0.2250 - val_auc: 0.5604 - val_loss: 6.1963 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.6424 - auc: 0.8906 - loss: 5.5105 - precision: 0.6836 - recall: 0.6112 - val_accuracy: 0.2375 - val_auc: 0.5689 - val_loss: 6.1794 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.6921 - auc: 0.9220 - loss: 5.3419 - precision: 0.7473 - recall: 0.6571 - val_accuracy: 0.2625 - val_auc: 0.5843 - val_loss: 6.1594 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.6956 - auc: 0.9305 - loss: 5.2832 - precision: 0.7369 - recall: 0.6538 - val_accuracy: 0.2750 - val_auc: 0.6065 - val_loss: 6.1260 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.7369 - auc: 0.9409 - loss: 5.1925 - precision: 0.7646 - recall: 0.6919 - val_accuracy: 0.3375 - val_auc: 0.6278 - val_loss: 6.0981 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.7316 - auc: 0.9489 - loss: 5.1382 - precision: 0.7857 - recall: 0.6673 - val_accuracy: 0.3500 - val_auc: 0.6522 - val_loss: 6.0671 - val_precision: 1.0000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.7927 - auc: 0.9566 - loss: 5.0781 - precision: 0.8218 - recall: 0.7333 - val_accuracy: 0.3625 - val_auc: 0.6700 - val_loss: 6.0247 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.8000 - auc: 0.9561 - loss: 5.0761 - precision: 0.8019 - recall: 0.7524 - val_accuracy: 0.3750 - val_auc: 0.6885 - val_loss: 5.9815 - val_precision: 0.8571 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.7903 - auc: 0.9696 - loss: 4.9697 - precision: 0.8234 - recall: 0.7670 - val_accuracy: 0.3625 - val_auc: 0.7047 - val_loss: 5.9485 - val_precision: 0.7778 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.8275 - auc: 0.9777 - loss: 4.9013 - precision: 0.8549 - recall: 0.8067 - val_accuracy: 0.3875 - val_auc: 0.7198 - val_loss: 5.9147 - val_precision: 0.6875 - val_recall: 0.1375 - learning_rate: 3.0000e-05
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.8650 - auc: 0.9852 - loss: 4.8001 - precision: 0.8873 - recall: 0.8389 - val_accuracy: 0.4625 - val_auc: 0.7437 - val_loss: 5.8764 - val_precision: 0.7308 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.8573 - auc: 0.9806 - loss: 4.8432 - precision: 0.8793 - recall: 0.8196 - val_accuracy: 0.5125 - val_auc: 0.7637 - val_loss: 5.8457 - val_precision: 0.6471 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9015 - auc: 0.9887 - loss: 4.7355 - precision: 0.9139 - recall: 0.8826 - val_accuracy: 0.5500 - val_auc: 0.7763 - val_loss: 5.8028 - val_precision: 0.6829 - val_recall: 0.3500 - learning_rate: 3.0000e-05
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9284 - auc: 0.9930 - loss: 4.6829 - precision: 0.9510 - recall: 0.8882 - val_accuracy: 0.5250 - val_auc: 0.7771 - val_loss: 5.8187 - val_precision: 0.6889 - val_recall: 0.3875 - learning_rate: 3.0000e-05
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.9081 - auc: 0.9939 - loss: 4.6566 - precision: 0.9122 - recall: 0.8960 - val_accuracy: 0.5625 - val_auc: 0.7769 - val_loss: 5.8536 - val_precision: 0.6491 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 5 Results:
# Accuracy: 52.50%
# AUC: 0.7675
#
# === CROSS-VALIDATION RESULTS ===
# Accuracy: 0.6025 ± 0.0756
# Precision: 0.5664 ± 0.1368
# Recall: 0.6025 ± 0.0756
# F1: 0.5661 ± 0.1097
# Auc: 0.8259 ± 0.0528
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step
# Making prediction on test image...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Prediction Probabilities:
# NO Dr: 93.65%
# Mild: 4.08%
# Proliferative_DR: 1.89%
# Severe Dr: 0.22%
# Moderate: 0.16%
