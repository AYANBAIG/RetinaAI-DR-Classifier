# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19  # Changed from VGG16 to VGG19
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, confusion_matrix, 
                           precision_score, recall_score, f1_score, 
                           accuracy_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc
import math
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
from collections import Counter

# ====== CONFIGURATION ======
class Config:
    BATCH_SIZE = 8
    IMG_SIZE = (256, 256)  # VGG19 typically uses 224x224, but we'll keep your size
    NUM_FOLDS = 5
    EPOCHS = 50
    LEARNING_RATE = 3e-5
    DROPOUT_RATE = 0.5
    SE_RATIO = 16
    BASE_DIR = '/kaggle/input/local-preprocessed-dataset/LOCAL PREPROCESSED DATASET'
    SEED = 42
    MIN_SAMPLES = 20

# ====== DATA AUGMENTATION ======
def create_augmenter():
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.95, 1.05],
        fill_mode='reflect',
        validation_split=0.2
    )

# ====== SQUEEZE-EXCITATION BLOCK ======
def se_block(input_tensor, ratio=Config.SE_RATIO):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(channels // ratio, activation='relu', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    
    return layers.Multiply()([input_tensor, se])

# ====== ENHANCED VGG19 MODEL ======  # Changed from VGG16 to VGG19
def build_enhanced_vgg19(num_classes):  # Changed function name
    base_model = VGG19(  # Changed from VGG16 to VGG19
        weights='imagenet',
        include_top=False,
        input_shape=(*Config.IMG_SIZE, 3)
    )
    
    # Freeze all convolutional layers
    for layer in base_model.layers:
        layer.trainable = False
    
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    x = layers.Dense(256, activation='relu', 
                    kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=outputs)
    
    optimizer = optimizers.Adam(
        learning_rate=Config.LEARNING_RATE,
        clipnorm=1.0
    )
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')]
    )
    
    return model

# ====== CUSTOM DATA GENERATOR ======
class AdvancedDataGenerator(Sequence):
    def __init__(self, filepaths, labels, datagen, batch_size=32, img_size=(256,256), shuffle=True):
        self.filepaths = filepaths
        self.labels = labels
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.filepaths) / self.batch_size)

    def __getitem__(self, index):
        batch_files = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        images = []
        for filepath in batch_files:
            img = image.load_img(filepath, target_size=self.img_size)
            img_array = image.img_to_array(img)
            img_array = self.datagen.standardize(img_array)
            images.append(img_array)
            
        return np.array(images), tf.keras.utils.to_categorical(batch_labels, num_classes=len(set(self.labels)))

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.filepaths))
            np.random.shuffle(indices)
            self.filepaths = [self.filepaths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# ====== TRAINING PIPELINE ======
def run_training():
    # Initialize data
    datagen = create_augmenter()
    train_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=Config.SEED
    )
    
    # Data integrity checks
    print("\n=== DATA VALIDATION ===")
    print("Class distribution in training:", Counter(train_gen.labels))
    
    val_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=Config.SEED
    )
    print("Class distribution in validation:", Counter(val_gen.labels))
    
    # Verify no overlap
    train_files = set(train_gen.filepaths)
    val_files = set(val_gen.filepaths)
    print(f"Number of overlapping files: {len(train_files & val_files)}")
    
    class_indices = train_gen.class_indices
    X = train_gen.filepaths
    y = train_gen.labels
    
    # Cross-validation setup
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    fold_no = 1
    history_list = []
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1': [],
        'auc': []
    }

    for train_idx, val_idx in kf.split(X, y):
        print(f"\n🔵 Fold {fold_no}")
        
        # Create generators
        simple_datagen = ImageDataGenerator(rescale=1./255)
        train_data = AdvancedDataGenerator(
            [X[i] for i in train_idx],
            [y[i] for i in train_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE
        )
        val_data = AdvancedDataGenerator(
            [X[i] for i in val_idx],
            [y[i] for i in val_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE,
            shuffle=False
        )
        
        # Build model - changed to VGG19
        model = build_enhanced_vgg19(len(class_indices))
        
        # Callbacks
        callbacks_list = [
            callbacks.EarlyStopping(
                monitor='val_auc',
                patience=15,
                mode='max',
                baseline=0.85,
                restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=1e-6,
                cooldown=2
            ),
            callbacks.ModelCheckpoint(
                f'vgg19_fold_{fold_no}.keras',  # Changed filename to vgg19
                monitor='val_auc',
                save_best_only=True,
                mode='max'
            )
        ]
        
        # Train
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=Config.EPOCHS,
            callbacks=callbacks_list,
            verbose=1
        )
        history_list.append(history)
        
        # Evaluate
        val_preds = model.predict(val_data, verbose=0)
        val_preds_labels = np.argmax(val_preds, axis=1)
        val_true_labels = val_data.labels
        
        # Store metrics
        metrics['accuracy'].append(accuracy_score(val_true_labels, val_preds_labels))
        metrics['precision'].append(precision_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['recall'].append(recall_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['f1'].append(f1_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['auc'].append(np.mean(history.history['val_auc'][-5:]))
        
        print(f"✅ Fold {fold_no} Results:")
        print(f"Accuracy: {metrics['accuracy'][-1]*100:.2f}%")
        print(f"AUC: {metrics['auc'][-1]:.4f}")
        
        fold_no += 1
        tf.keras.backend.clear_session()
        gc.collect()
    
    # Final results
    print("\n=== CROSS-VALIDATION RESULTS ===")
    for metric, values in metrics.items():
        print(f"{metric.capitalize()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
    
    return history_list, metrics, class_indices, X, y

# ====== VISUALIZATION ======
def plot_results(history_list, metrics, class_indices, X, y):
    # Training curves
    plt.figure(figsize=(20, 10))
    
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_accuracy'], alpha=0.3, color='orange')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['loss'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_loss'], alpha=0.3, color='orange')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
    # Confusion matrix for best fold
    best_fold = np.argmax(metrics['auc']) + 1
    model = tf.keras.models.load_model(f'vgg19_fold_{best_fold}.keras')  # Changed to vgg19
    
    # Get validation data for best fold
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    splits = list(kf.split(X, y))
    _, val_idx = splits[best_fold-1]
    
    val_data = AdvancedDataGenerator(
        [X[i] for i in val_idx],
        [y[i] for i in val_idx],
        ImageDataGenerator(rescale=1./255),
        Config.BATCH_SIZE,
        Config.IMG_SIZE,
        shuffle=False
    )
    
    val_preds = model.predict(val_data)
    val_preds_labels = np.argmax(val_preds, axis=1)
    
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(val_data.labels, val_preds_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_indices.keys(),
                yticklabels=class_indices.keys())
    plt.title(f'VGG19 Confusion Matrix (Fold {best_fold})')  # Changed to VGG19
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# ====== PREDICTION UTILITIES ======
class VGGPredictor:  # Kept the same name as it's generic
    def __init__(self, model_path, class_indices):
        self.model = tf.keras.models.load_model(model_path)
        self.class_indices = class_indices
        self.img_size = Config.IMG_SIZE
        
    def predict_image(self, image_path):
        """Make prediction with visualization."""
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Image not found: {image_path}")
            
        img = image.load_img(image_path, target_size=self.img_size)
        img_array = image.img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        pred = self.model.predict(img_array)[0]
        sorted_idx = np.argsort(pred)[::-1]
        
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Input Image')
        
        plt.subplot(1, 2, 2)
        colors = plt.cm.rainbow(np.linspace(0, 1, len(self.class_indices)))
        for i, idx in enumerate(sorted_idx[:3]):
            plt.barh(i, pred[idx]*100, color=colors[idx])
            plt.text(pred[idx]*100 + 1, i, 
                    f"{list(self.class_indices.keys())[idx]}: {pred[idx]*100:.2f}%",
                    va='center')
        plt.yticks([])
        plt.xlabel('Confidence (%)')
        plt.title('Top Predictions')
        plt.xlim(0, 100)
        plt.tight_layout()
        plt.show()
        
        return {list(self.class_indices.keys())[i]: float(pred[i]) for i in sorted_idx}

# ====== MAIN EXECUTION ======
if __name__ == "__main__":
    # Run training
    history_list, metrics, class_indices, X, y = run_training()
    
    # Visualize results
    plot_results(history_list, metrics, class_indices, X, y)
    
    # Example prediction
    predictor = VGGPredictor('vgg19_fold_1.keras', class_indices)  # Changed to vgg19
    test_image = os.path.join(Config.BASE_DIR, 'NO Dr/005b95c28852.png')
    
    if os.path.exists(test_image):
        print("\nMaking prediction on test image...")
        predictions = predictor.predict_image(test_image)
        print("\nPrediction Probabilities:")
        for cls, prob in predictions.items():
            print(f"{cls}: {prob*100:.2f}%")
    else:
        print(f"\nTest image not found at: {test_image}")
        print("Please provide a valid image path for prediction.")
# Out:
# Found 400 images belonging to 5 classes.
#
# === DATA VALIDATION ===
# Class distribution in training: Counter({0: 80, 1: 80, 2: 80, 3: 80, 4: 80})
# Found 100 images belonging to 5 classes.
# Class distribution in validation: Counter({0: 20, 1: 20, 2: 20, 3: 20, 4: 20})
# Number of overlapping files: 0
#
# 🔵 Fold 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - accuracy: 0.1658 - auc: 0.4771 - loss: 6.0850 - precision: 0.1414 - recall: 0.0986 - val_accuracy: 0.1500 - val_auc: 0.4594 - val_loss: 5.3360 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1574 - auc: 0.5085 - loss: 5.9532 - precision: 0.1473 - recall: 0.1016 - val_accuracy: 0.2625 - val_auc: 0.4633 - val_loss: 5.1128 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2020 - auc: 0.5319 - loss: 5.6764 - precision: 0.1940 - recall: 0.1385 - val_accuracy: 0.2875 - val_auc: 0.4752 - val_loss: 4.9618 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2012 - auc: 0.5242 - loss: 5.6807 - precision: 0.2081 - recall: 0.1244 - val_accuracy: 0.2375 - val_auc: 0.4793 - val_loss: 4.8627 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.2389 - auc: 0.5309 - loss: 5.6017 - precision: 0.2381 - recall: 0.1568 - val_accuracy: 0.2125 - val_auc: 0.5172 - val_loss: 4.7884 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2077 - auc: 0.5096 - loss: 5.6054 - precision: 0.2157 - recall: 0.1377 - val_accuracy: 0.2125 - val_auc: 0.5394 - val_loss: 4.7276 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2249 - auc: 0.5337 - loss: 5.5211 - precision: 0.2320 - recall: 0.1613 - val_accuracy: 0.2125 - val_auc: 0.5485 - val_loss: 4.6777 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2031 - auc: 0.5065 - loss: 5.5239 - precision: 0.1975 - recall: 0.1221 - val_accuracy: 0.2875 - val_auc: 0.5606 - val_loss: 4.6329 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1908 - auc: 0.5250 - loss: 5.4308 - precision: 0.1654 - recall: 0.0938 - val_accuracy: 0.3250 - val_auc: 0.5733 - val_loss: 4.5858 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2075 - auc: 0.5589 - loss: 5.1445 - precision: 0.2709 - recall: 0.1577 - val_accuracy: 0.3375 - val_auc: 0.5818 - val_loss: 4.5410 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2262 - auc: 0.5361 - loss: 5.2024 - precision: 0.1875 - recall: 0.1161 - val_accuracy: 0.3375 - val_auc: 0.5921 - val_loss: 4.4906 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2310 - auc: 0.5353 - loss: 5.2609 - precision: 0.2083 - recall: 0.1415 - val_accuracy: 0.3500 - val_auc: 0.5959 - val_loss: 4.4491 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2041 - auc: 0.5237 - loss: 5.1534 - precision: 0.2129 - recall: 0.1262 - val_accuracy: 0.3625 - val_auc: 0.6033 - val_loss: 4.4024 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1731 - auc: 0.4907 - loss: 5.2294 - precision: 0.1889 - recall: 0.1123 - val_accuracy: 0.3375 - val_auc: 0.6092 - val_loss: 4.3620 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2726 - auc: 0.5335 - loss: 5.0459 - precision: 0.2818 - recall: 0.1645 - val_accuracy: 0.3500 - val_auc: 0.6129 - val_loss: 4.3263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2009 - auc: 0.4990 - loss: 5.1191 - precision: 0.1465 - recall: 0.0885 - val_accuracy: 0.3250 - val_auc: 0.6140 - val_loss: 4.2901 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.2280 - auc: 0.5173 - loss: 5.0138 - precision: 0.2483 - recall: 0.1336 - val_accuracy: 0.3500 - val_auc: 0.6207 - val_loss: 4.2537 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2431 - auc: 0.5266 - loss: 4.9505 - precision: 0.2268 - recall: 0.1321 - val_accuracy: 0.3500 - val_auc: 0.6262 - val_loss: 4.2148 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2400 - auc: 0.5487 - loss: 4.7849 - precision: 0.2554 - recall: 0.1677 - val_accuracy: 0.3375 - val_auc: 0.6283 - val_loss: 4.1725 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2446 - auc: 0.5662 - loss: 4.7189 - precision: 0.2498 - recall: 0.1468 - val_accuracy: 0.3375 - val_auc: 0.6364 - val_loss: 4.1261 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2403 - auc: 0.5594 - loss: 4.6816 - precision: 0.2842 - recall: 0.1650 - val_accuracy: 0.3375 - val_auc: 0.6393 - val_loss: 4.0893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2162 - auc: 0.5546 - loss: 4.7322 - precision: 0.2357 - recall: 0.1326 - val_accuracy: 0.3500 - val_auc: 0.6447 - val_loss: 4.0555 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.2120 - auc: 0.5027 - loss: 4.8364 - precision: 0.2040 - recall: 0.1069 - val_accuracy: 0.3500 - val_auc: 0.6472 - val_loss: 4.0269 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2231 - auc: 0.5302 - loss: 4.7833 - precision: 0.2587 - recall: 0.1448 - val_accuracy: 0.3875 - val_auc: 0.6558 - val_loss: 3.9938 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2059 - auc: 0.5230 - loss: 4.7166 - precision: 0.2179 - recall: 0.1334 - val_accuracy: 0.4125 - val_auc: 0.6634 - val_loss: 3.9633 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2035 - auc: 0.5162 - loss: 4.6860 - precision: 0.2188 - recall: 0.1285 - val_accuracy: 0.4125 - val_auc: 0.6708 - val_loss: 3.9316 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2128 - auc: 0.5020 - loss: 4.6935 - precision: 0.1789 - recall: 0.0986 - val_accuracy: 0.4000 - val_auc: 0.6731 - val_loss: 3.9004 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2313 - auc: 0.5546 - loss: 4.5138 - precision: 0.2329 - recall: 0.1375 - val_accuracy: 0.4125 - val_auc: 0.6762 - val_loss: 3.8698 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2469 - auc: 0.5443 - loss: 4.5337 - precision: 0.2821 - recall: 0.1425 - val_accuracy: 0.4125 - val_auc: 0.6866 - val_loss: 3.8351 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2908 - auc: 0.5823 - loss: 4.3908 - precision: 0.2848 - recall: 0.1631 - val_accuracy: 0.4250 - val_auc: 0.6868 - val_loss: 3.8084 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2415 - auc: 0.5523 - loss: 4.4932 - precision: 0.2837 - recall: 0.1458 - val_accuracy: 0.4250 - val_auc: 0.6904 - val_loss: 3.7864 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2417 - auc: 0.5557 - loss: 4.3661 - precision: 0.2947 - recall: 0.1567 - val_accuracy: 0.4000 - val_auc: 0.6892 - val_loss: 3.7527 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 1 Results:
# Accuracy: 42.50%
# AUC: 0.6858
#
# 🔵 Fold 2
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.2260 - auc: 0.4846 - loss: 5.9300 - precision: 0.2244 - recall: 0.1355 - val_accuracy: 0.2125 - val_auc: 0.5518 - val_loss: 4.9626 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1834 - auc: 0.4717 - loss: 6.0487 - precision: 0.1595 - recall: 0.0981 - val_accuracy: 0.1875 - val_auc: 0.5604 - val_loss: 4.9053 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1941 - auc: 0.5071 - loss: 5.7895 - precision: 0.2434 - recall: 0.1605 - val_accuracy: 0.1250 - val_auc: 0.5723 - val_loss: 4.8528 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2109 - auc: 0.5149 - loss: 5.6568 - precision: 0.1786 - recall: 0.1092 - val_accuracy: 0.1750 - val_auc: 0.5735 - val_loss: 4.8012 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2331 - auc: 0.5145 - loss: 5.5961 - precision: 0.2022 - recall: 0.1363 - val_accuracy: 0.2500 - val_auc: 0.5722 - val_loss: 4.7538 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2336 - auc: 0.5084 - loss: 5.5604 - precision: 0.2185 - recall: 0.1443 - val_accuracy: 0.3000 - val_auc: 0.5793 - val_loss: 4.7030 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2453 - auc: 0.5631 - loss: 5.2424 - precision: 0.2147 - recall: 0.1270 - val_accuracy: 0.3000 - val_auc: 0.5796 - val_loss: 4.6581 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2127 - auc: 0.5204 - loss: 5.4418 - precision: 0.2259 - recall: 0.1342 - val_accuracy: 0.3000 - val_auc: 0.5784 - val_loss: 4.6150 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2278 - auc: 0.5129 - loss: 5.4240 - precision: 0.2066 - recall: 0.1350 - val_accuracy: 0.3125 - val_auc: 0.5787 - val_loss: 4.5739 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2288 - auc: 0.5481 - loss: 5.1303 - precision: 0.2592 - recall: 0.1514 - val_accuracy: 0.3500 - val_auc: 0.5897 - val_loss: 4.5263 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2301 - auc: 0.5744 - loss: 5.0992 - precision: 0.2507 - recall: 0.1524 - val_accuracy: 0.3375 - val_auc: 0.5913 - val_loss: 4.4832 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2267 - auc: 0.5444 - loss: 5.1800 - precision: 0.2247 - recall: 0.1324 - val_accuracy: 0.3375 - val_auc: 0.5929 - val_loss: 4.4436 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2230 - auc: 0.5324 - loss: 5.1482 - precision: 0.1980 - recall: 0.1205 - val_accuracy: 0.3125 - val_auc: 0.5951 - val_loss: 4.4019 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.1663 - auc: 0.4858 - loss: 5.3692 - precision: 0.1976 - recall: 0.1237 - val_accuracy: 0.3500 - val_auc: 0.5899 - val_loss: 4.3706 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2539 - auc: 0.5600 - loss: 4.9586 - precision: 0.3099 - recall: 0.1835 - val_accuracy: 0.3625 - val_auc: 0.5931 - val_loss: 4.3370 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 2 Results:
# Accuracy: 31.25%
# AUC: 0.5925
#
# 🔵 Fold 3
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 98ms/step - accuracy: 0.2178 - auc: 0.5172 - loss: 5.8070 - precision: 0.1877 - recall: 0.1226 - val_accuracy: 0.1125 - val_auc: 0.5411 - val_loss: 4.9880 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2197 - auc: 0.5263 - loss: 5.7001 - precision: 0.2243 - recall: 0.1460 - val_accuracy: 0.1250 - val_auc: 0.5509 - val_loss: 4.9063 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1884 - auc: 0.5287 - loss: 5.6263 - precision: 0.1914 - recall: 0.1240 - val_accuracy: 0.1875 - val_auc: 0.5720 - val_loss: 4.8408 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2138 - auc: 0.5191 - loss: 5.6362 - precision: 0.2390 - recall: 0.1362 - val_accuracy: 0.2125 - val_auc: 0.6013 - val_loss: 4.7787 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1808 - auc: 0.4983 - loss: 5.6190 - precision: 0.1720 - recall: 0.1016 - val_accuracy: 0.3500 - val_auc: 0.6373 - val_loss: 4.7174 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2186 - auc: 0.5055 - loss: 5.5664 - precision: 0.1929 - recall: 0.1129 - val_accuracy: 0.3250 - val_auc: 0.6484 - val_loss: 4.6638 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2194 - auc: 0.4859 - loss: 5.7054 - precision: 0.1678 - recall: 0.1167 - val_accuracy: 0.4000 - val_auc: 0.6778 - val_loss: 4.6021 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1551 - auc: 0.5088 - loss: 5.3845 - precision: 0.1535 - recall: 0.0957 - val_accuracy: 0.4250 - val_auc: 0.6846 - val_loss: 4.5518 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1854 - auc: 0.5146 - loss: 5.3788 - precision: 0.2002 - recall: 0.1231 - val_accuracy: 0.4500 - val_auc: 0.6946 - val_loss: 4.5046 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2023 - auc: 0.5050 - loss: 5.3407 - precision: 0.1955 - recall: 0.1145 - val_accuracy: 0.3875 - val_auc: 0.6914 - val_loss: 4.4601 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2068 - auc: 0.5287 - loss: 5.2385 - precision: 0.2248 - recall: 0.1272 - val_accuracy: 0.3625 - val_auc: 0.6802 - val_loss: 4.4238 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2019 - auc: 0.5045 - loss: 5.2604 - precision: 0.2482 - recall: 0.1588 - val_accuracy: 0.3500 - val_auc: 0.6922 - val_loss: 4.3782 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2457 - auc: 0.5502 - loss: 5.0147 - precision: 0.2414 - recall: 0.1301 - val_accuracy: 0.3625 - val_auc: 0.7125 - val_loss: 4.3314 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1935 - auc: 0.4988 - loss: 5.1953 - precision: 0.1854 - recall: 0.1028 - val_accuracy: 0.4125 - val_auc: 0.7358 - val_loss: 4.2816 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2614 - auc: 0.5424 - loss: 4.9694 - precision: 0.2272 - recall: 0.1235 - val_accuracy: 0.4375 - val_auc: 0.7454 - val_loss: 4.2399 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2529 - auc: 0.5067 - loss: 5.1067 - precision: 0.2458 - recall: 0.1410 - val_accuracy: 0.4500 - val_auc: 0.7450 - val_loss: 4.1966 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# ✅ Fold 3 Results:
# Accuracy: 43.75%
# AUC: 0.7262
#
# 🔵 Fold 4
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - accuracy: 0.1893 - auc: 0.5021 - loss: 6.0627 - precision: 0.1875 - recall: 0.1274 - val_accuracy: 0.2250 - val_auc: 0.4634 - val_loss: 5.0372 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2115 - auc: 0.5143 - loss: 5.9629 - precision: 0.1993 - recall: 0.1361 - val_accuracy: 0.2500 - val_auc: 0.4771 - val_loss: 4.9594 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2021 - auc: 0.4789 - loss: 6.1547 - precision: 0.2072 - recall: 0.1387 - val_accuracy: 0.2750 - val_auc: 0.5231 - val_loss: 4.8815 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2115 - auc: 0.5375 - loss: 5.8344 - precision: 0.2130 - recall: 0.1433 - val_accuracy: 0.2000 - val_auc: 0.5351 - val_loss: 4.8315 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1700 - auc: 0.5004 - loss: 5.7629 - precision: 0.1749 - recall: 0.1148 - val_accuracy: 0.2625 - val_auc: 0.5369 - val_loss: 4.7867 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2014 - auc: 0.5220 - loss: 5.5634 - precision: 0.2026 - recall: 0.1352 - val_accuracy: 0.2750 - val_auc: 0.5398 - val_loss: 4.7536 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.2131 - auc: 0.5045 - loss: 5.6836 - precision: 0.2023 - recall: 0.1297 - val_accuracy: 0.2500 - val_auc: 0.5362 - val_loss: 4.7218 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2924 - auc: 0.5236 - loss: 5.4039 - precision: 0.2722 - recall: 0.1753 - val_accuracy: 0.2500 - val_auc: 0.5390 - val_loss: 4.6916 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2375 - auc: 0.5451 - loss: 5.2489 - precision: 0.2268 - recall: 0.1366 - val_accuracy: 0.2500 - val_auc: 0.5417 - val_loss: 4.6663 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2275 - auc: 0.5671 - loss: 5.1612 - precision: 0.2178 - recall: 0.1412 - val_accuracy: 0.2500 - val_auc: 0.5449 - val_loss: 4.6249 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2363 - auc: 0.5085 - loss: 5.3573 - precision: 0.2167 - recall: 0.1391 - val_accuracy: 0.2625 - val_auc: 0.5490 - val_loss: 4.5969 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.1935 - auc: 0.4962 - loss: 5.4141 - precision: 0.2100 - recall: 0.1243 - val_accuracy: 0.2625 - val_auc: 0.5502 - val_loss: 4.5540 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2288 - auc: 0.5518 - loss: 5.0095 - precision: 0.2525 - recall: 0.1483 - val_accuracy: 0.2625 - val_auc: 0.5538 - val_loss: 4.5098 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2230 - auc: 0.5243 - loss: 5.1666 - precision: 0.1819 - recall: 0.1213 - val_accuracy: 0.2625 - val_auc: 0.5576 - val_loss: 4.4594 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2189 - auc: 0.5269 - loss: 5.0401 - precision: 0.2075 - recall: 0.1327 - val_accuracy: 0.2750 - val_auc: 0.5628 - val_loss: 4.4181 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2858 - auc: 0.5643 - loss: 4.8981 - precision: 0.3046 - recall: 0.1725 - val_accuracy: 0.2750 - val_auc: 0.5672 - val_loss: 4.3861 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2232 - auc: 0.5150 - loss: 5.0517 - precision: 0.2502 - recall: 0.1430 - val_accuracy: 0.2625 - val_auc: 0.5715 - val_loss: 4.3421 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1982 - auc: 0.5056 - loss: 4.9824 - precision: 0.1916 - recall: 0.1132 - val_accuracy: 0.2750 - val_auc: 0.5740 - val_loss: 4.3098 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2235 - auc: 0.5244 - loss: 4.8912 - precision: 0.1948 - recall: 0.1197 - val_accuracy: 0.2750 - val_auc: 0.5751 - val_loss: 4.2788 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2071 - auc: 0.5092 - loss: 4.9344 - precision: 0.2784 - recall: 0.1547 - val_accuracy: 0.2750 - val_auc: 0.5785 - val_loss: 4.2390 - val_precision: 0.5000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1854 - auc: 0.5060 - loss: 4.8816 - precision: 0.1973 - recall: 0.1085 - val_accuracy: 0.2750 - val_auc: 0.5838 - val_loss: 4.2011 - val_precision: 0.6000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1946 - auc: 0.5025 - loss: 4.8054 - precision: 0.1974 - recall: 0.1052 - val_accuracy: 0.2750 - val_auc: 0.5879 - val_loss: 4.1630 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1836 - auc: 0.5177 - loss: 4.8294 - precision: 0.1688 - recall: 0.1052 - val_accuracy: 0.2750 - val_auc: 0.5897 - val_loss: 4.1327 - val_precision: 0.6000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.1871 - auc: 0.4819 - loss: 4.9812 - precision: 0.1715 - recall: 0.1063 - val_accuracy: 0.2750 - val_auc: 0.5950 - val_loss: 4.0951 - val_precision: 0.6000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2744 - auc: 0.5741 - loss: 4.5829 - precision: 0.2410 - recall: 0.1400 - val_accuracy: 0.3000 - val_auc: 0.6000 - val_loss: 4.0575 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2374 - auc: 0.5327 - loss: 4.7157 - precision: 0.2611 - recall: 0.1686 - val_accuracy: 0.3125 - val_auc: 0.6070 - val_loss: 4.0149 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2906 - auc: 0.5796 - loss: 4.3702 - precision: 0.2815 - recall: 0.1572 - val_accuracy: 0.3125 - val_auc: 0.6093 - val_loss: 3.9834 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2672 - auc: 0.5719 - loss: 4.4698 - precision: 0.2685 - recall: 0.1480 - val_accuracy: 0.3250 - val_auc: 0.6159 - val_loss: 3.9422 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2363 - auc: 0.5649 - loss: 4.4846 - precision: 0.2594 - recall: 0.1619 - val_accuracy: 0.3875 - val_auc: 0.6230 - val_loss: 3.9066 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.2398 - auc: 0.5689 - loss: 4.3383 - precision: 0.2738 - recall: 0.1513 - val_accuracy: 0.3875 - val_auc: 0.6213 - val_loss: 3.8819 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 4 Results:
# Accuracy: 38.75%
# AUC: 0.6153
#
# 🔵 Fold 5
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - accuracy: 0.1642 - auc: 0.4928 - loss: 6.0635 - precision: 0.1618 - recall: 0.1093 - val_accuracy: 0.2250 - val_auc: 0.5147 - val_loss: 5.0125 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1613 - auc: 0.4871 - loss: 6.0040 - precision: 0.1924 - recall: 0.1280 - val_accuracy: 0.2375 - val_auc: 0.5241 - val_loss: 4.9319 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1823 - auc: 0.5198 - loss: 5.8133 - precision: 0.1757 - recall: 0.1310 - val_accuracy: 0.2125 - val_auc: 0.5316 - val_loss: 4.8686 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.1838 - auc: 0.4834 - loss: 5.9408 - precision: 0.1695 - recall: 0.1080 - val_accuracy: 0.2750 - val_auc: 0.5306 - val_loss: 4.8142 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.2377 - auc: 0.5103 - loss: 5.7145 - precision: 0.2457 - recall: 0.1492 - val_accuracy: 0.2500 - val_auc: 0.5405 - val_loss: 4.7626 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.1777 - auc: 0.5158 - loss: 5.5476 - precision: 0.2292 - recall: 0.1399 - val_accuracy: 0.2375 - val_auc: 0.5362 - val_loss: 4.7156 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2142 - auc: 0.5084 - loss: 5.6239 - precision: 0.2171 - recall: 0.1290 - val_accuracy: 0.2875 - val_auc: 0.5453 - val_loss: 4.6687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2150 - auc: 0.5356 - loss: 5.4347 - precision: 0.2404 - recall: 0.1775 - val_accuracy: 0.3125 - val_auc: 0.5469 - val_loss: 4.6230 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2178 - auc: 0.5038 - loss: 5.5142 - precision: 0.1929 - recall: 0.1287 - val_accuracy: 0.3375 - val_auc: 0.5562 - val_loss: 4.5794 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2079 - auc: 0.5165 - loss: 5.4285 - precision: 0.1833 - recall: 0.1127 - val_accuracy: 0.3125 - val_auc: 0.5580 - val_loss: 4.5352 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2313 - auc: 0.5050 - loss: 5.3991 - precision: 0.2070 - recall: 0.1210 - val_accuracy: 0.3375 - val_auc: 0.5659 - val_loss: 4.4956 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2079 - auc: 0.5236 - loss: 5.1965 - precision: 0.2190 - recall: 0.1371 - val_accuracy: 0.3375 - val_auc: 0.5691 - val_loss: 4.4543 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2285 - auc: 0.5435 - loss: 5.2125 - precision: 0.2481 - recall: 0.1728 - val_accuracy: 0.3375 - val_auc: 0.5784 - val_loss: 4.4096 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.1802 - auc: 0.5066 - loss: 5.2038 - precision: 0.1977 - recall: 0.1204 - val_accuracy: 0.3375 - val_auc: 0.5818 - val_loss: 4.3687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2767 - auc: 0.5705 - loss: 4.8803 - precision: 0.2545 - recall: 0.1383 - val_accuracy: 0.3375 - val_auc: 0.5848 - val_loss: 4.3338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2734 - auc: 0.5489 - loss: 4.9433 - precision: 0.2734 - recall: 0.1596 - val_accuracy: 0.3500 - val_auc: 0.6006 - val_loss: 4.2862 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2606 - auc: 0.5841 - loss: 4.7709 - precision: 0.2723 - recall: 0.1638 - val_accuracy: 0.3875 - val_auc: 0.6159 - val_loss: 4.2411 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.2360 - auc: 0.5330 - loss: 4.9349 - precision: 0.1665 - recall: 0.0961 - val_accuracy: 0.4000 - val_auc: 0.6347 - val_loss: 4.1952 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.1801 - auc: 0.5152 - loss: 5.0372 - precision: 0.1865 - recall: 0.1221 - val_accuracy: 0.3500 - val_auc: 0.6441 - val_loss: 4.1550 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.2290 - auc: 0.5585 - loss: 4.7263 - precision: 0.2481 - recall: 0.1518 - val_accuracy: 0.3375 - val_auc: 0.6498 - val_loss: 4.1173 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.1879 - auc: 0.5331 - loss: 4.8500 - precision: 0.2425 - recall: 0.1374 - val_accuracy: 0.3250 - val_auc: 0.6453 - val_loss: 4.0878 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 5 Results:
# Accuracy: 33.75%
# AUC: 0.6380
#
# === CROSS-VALIDATION RESULTS ===
# Accuracy: 0.3800 ± 0.0485
# Precision: 0.3893 ± 0.1421
# Recall: 0.3800 ± 0.0485
# F1: 0.3130 ± 0.0748
# Auc: 0.6515 ± 0.0484
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Making prediction on test image...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# Prediction Probabilities:
# Severe Dr: 30.00%
# Proliferative_DR: 26.06%
# Moderate: 18.07%
# NO Dr: 13.96%
# Mild: 11.90%
