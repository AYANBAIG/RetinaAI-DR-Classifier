# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121  # Changed from VGG19 to DenseNet121
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from sklearn.metrics import (classification_report, confusion_matrix, 
                           precision_score, recall_score, f1_score, 
                           accuracy_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import gc
import math
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import Sequence
from collections import Counter

# ====== CONFIGURATION ======
class Config:
    BATCH_SIZE = 8
    IMG_SIZE = (256, 256)  # DenseNet typically uses 224x224, but we'll keep your size
    NUM_FOLDS = 5
    EPOCHS = 50
    LEARNING_RATE = 3e-5
    DROPOUT_RATE = 0.5
    SE_RATIO = 16
    BASE_DIR = '/kaggle/input/local-preprocessed-dataset/LOCAL PREPROCESSED DATASET'
    SEED = 42
    MIN_SAMPLES = 20

# ====== DATA AUGMENTATION ======
def create_augmenter():
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.95, 1.05],
        fill_mode='reflect',
        validation_split=0.2
    )

# ====== SQUEEZE-EXCITATION BLOCK ======
def se_block(input_tensor, ratio=Config.SE_RATIO):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = layers.GlobalAveragePooling2D()(input_tensor)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(channels // ratio, activation='relu', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(channels, activation='sigmoid', 
                     kernel_initializer='he_normal', use_bias=False)(se)
    
    return layers.Multiply()([input_tensor, se])

# ====== ENHANCED DENSENET MODEL ======
def build_enhanced_densenet(num_classes):
    base_model = DenseNet121(
        weights='imagenet',
        include_top=False,
        input_shape=(*Config.IMG_SIZE, 3)
    )
    
    # Freeze all convolutional layers
    for layer in base_model.layers:
        layer.trainable = False
    
    x = base_model.output
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    x = layers.Dense(256, activation='relu', 
                    kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(Config.DROPOUT_RATE)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = models.Model(inputs=base_model.input, outputs=outputs)
    
    optimizer = optimizers.Adam(
        learning_rate=Config.LEARNING_RATE,
        clipnorm=1.0
    )
    
    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.AUC(name='auc')]
    )
    
    return model

# ====== CUSTOM DATA GENERATOR ======
class AdvancedDataGenerator(Sequence):
    def __init__(self, filepaths, labels, datagen, batch_size=32, img_size=(256,256), shuffle=True):
        self.filepaths = filepaths
        self.labels = labels
        self.datagen = datagen
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.filepaths) / self.batch_size)

    def __getitem__(self, index):
        batch_files = self.filepaths[index*self.batch_size:(index+1)*self.batch_size]
        batch_labels = self.labels[index*self.batch_size:(index+1)*self.batch_size]
        
        images = []
        for filepath in batch_files:
            img = image.load_img(filepath, target_size=self.img_size)
            img_array = image.img_to_array(img)
            img_array = self.datagen.standardize(img_array)
            images.append(img_array)
            
        return np.array(images), tf.keras.utils.to_categorical(batch_labels, num_classes=len(set(self.labels)))

    def on_epoch_end(self):
        if self.shuffle:
            indices = np.arange(len(self.filepaths))
            np.random.shuffle(indices)
            self.filepaths = [self.filepaths[i] for i in indices]
            self.labels = [self.labels[i] for i in indices]

# ====== TRAINING PIPELINE ======
def run_training():
    # Initialize data
    datagen = create_augmenter()
    train_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=Config.SEED
    )
    
    # Data integrity checks
    print("\n=== DATA VALIDATION ===")
    print("Class distribution in training:", Counter(train_gen.labels))
    
    val_gen = datagen.flow_from_directory(
        Config.BASE_DIR,
        target_size=Config.IMG_SIZE,
        batch_size=Config.BATCH_SIZE,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=Config.SEED
    )
    print("Class distribution in validation:", Counter(val_gen.labels))
    
    # Verify no overlap
    train_files = set(train_gen.filepaths)
    val_files = set(val_gen.filepaths)
    print(f"Number of overlapping files: {len(train_files & val_files)}")
    
    class_indices = train_gen.class_indices
    X = train_gen.filepaths
    y = train_gen.labels
    
    # Cross-validation setup
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    fold_no = 1
    history_list = []
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'f1': [],
        'auc': []
    }

    for train_idx, val_idx in kf.split(X, y):
        print(f"\n🔵 Fold {fold_no}")
        
        # Create generators
        simple_datagen = ImageDataGenerator(rescale=1./255)
        train_data = AdvancedDataGenerator(
            [X[i] for i in train_idx],
            [y[i] for i in train_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE
        )
        val_data = AdvancedDataGenerator(
            [X[i] for i in val_idx],
            [y[i] for i in val_idx],
            simple_datagen,
            Config.BATCH_SIZE,
            Config.IMG_SIZE,
            shuffle=False
        )
        
        # Build model - changed to DenseNet
        model = build_enhanced_densenet(len(class_indices))
        
        # Callbacks
        callbacks_list = [
            callbacks.EarlyStopping(
                monitor='val_auc',
                patience=15,
                mode='max',
                baseline=0.85,
                restore_best_weights=True
            ),
            callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.2,
                patience=8,
                min_lr=1e-6,
                cooldown=2
            ),
            callbacks.ModelCheckpoint(
                f'densenet_fold_{fold_no}.keras',  # Changed filename to densenet
                monitor='val_auc',
                save_best_only=True,
                mode='max'
            )
        ]
        
        # Train
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=Config.EPOCHS,
            callbacks=callbacks_list,
            verbose=1
        )
        history_list.append(history)
        
        # Evaluate
        val_preds = model.predict(val_data, verbose=0)
        val_preds_labels = np.argmax(val_preds, axis=1)
        val_true_labels = val_data.labels
        
        # Store metrics
        metrics['accuracy'].append(accuracy_score(val_true_labels, val_preds_labels))
        metrics['precision'].append(precision_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['recall'].append(recall_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['f1'].append(f1_score(val_true_labels, val_preds_labels, average='weighted'))
        metrics['auc'].append(np.mean(history.history['val_auc'][-5:]))
        
        print(f"✅ Fold {fold_no} Results:")
        print(f"Accuracy: {metrics['accuracy'][-1]*100:.2f}%")
        print(f"AUC: {metrics['auc'][-1]:.4f}")
        
        fold_no += 1
        tf.keras.backend.clear_session()
        gc.collect()
    
    # Final results
    print("\n=== CROSS-VALIDATION RESULTS ===")
    for metric, values in metrics.items():
        print(f"{metric.capitalize()}: {np.mean(values):.4f} ± {np.std(values):.4f}")
    
    return history_list, metrics, class_indices, X, y

# ====== VISUALIZATION ======
def plot_results(history_list, metrics, class_indices, X, y):
    # Training curves
    plt.figure(figsize=(20, 10))
    
    plt.subplot(1, 2, 1)
    for i, history in enumerate(history_list):
        plt.plot(history.history['accuracy'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_accuracy'], alpha=0.3, color='orange')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    plt.subplot(1, 2, 2)
    for i, history in enumerate(history_list):
        plt.plot(history.history['loss'], linestyle='--', alpha=0.3, color='blue')
        plt.plot(history.history['val_loss'], alpha=0.3, color='orange')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.tight_layout()
    plt.show()
    
    # Confusion matrix for best fold
    best_fold = np.argmax(metrics['auc']) + 1
    model = tf.keras.models.load_model(f'densenet_fold_{best_fold}.keras')  # Changed to densenet
    
    # Get validation data for best fold
    kf = KFold(n_splits=Config.NUM_FOLDS, shuffle=True, random_state=Config.SEED)
    splits = list(kf.split(X, y))
    _, val_idx = splits[best_fold-1]
    
    val_data = AdvancedDataGenerator(
        [X[i] for i in val_idx],
        [y[i] for i in val_idx],
        ImageDataGenerator(rescale=1./255),
        Config.BATCH_SIZE,
        Config.IMG_SIZE,
        shuffle=False
    )
    
    val_preds = model.predict(val_data)
    val_preds_labels = np.argmax(val_preds, axis=1)
    
    plt.figure(figsize=(12, 10))
    cm = confusion_matrix(val_data.labels, val_preds_labels)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_indices.keys(),
                yticklabels=class_indices.keys())
    plt.title(f'DenseNet Confusion Matrix (Fold {best_fold})')  # Changed to DenseNet
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# %%
# ====== PREDICTION UTILITIES ======
class DenseNetPredictor:  # Changed class name
    def __init__(self, model_path, class_indices):
        self.model = tf.keras.models.load_model(model_path)
        self.class_indices = class_indices
        self.img_size = Config.IMG_SIZE
        
    def predict_image(self, image_path):
        """Make prediction with visualization."""
        if not os.path.exists(image_path):
            raise FileNotFoundError(f"Image not found: {image_path}")
            
        img = image.load_img(image_path, target_size=self.img_size)
        img_array = image.img_to_array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)
        
        pred = self.model.predict(img_array)[0]
        sorted_idx = np.argsort(pred)[::-1]
        
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Input Image')
        
        plt.subplot(1, 2, 2)
        colors = plt.cm.rainbow(np.linspace(0, 1, len(self.class_indices)))
        for i, idx in enumerate(sorted_idx[:3]):
            plt.barh(i, pred[idx]*100, color=colors[idx])
            plt.text(pred[idx]*100 + 1, i, 
                    f"{list(self.class_indices.keys())[idx]}: {pred[idx]*100:.2f}%",
                    va='center')
        plt.yticks([])
        plt.xlabel('Confidence (%)')
        plt.title('Top Predictions')
        plt.xlim(0, 100)
        plt.tight_layout()
        plt.show()
        
        return {list(self.class_indices.keys())[i]: float(pred[i]) for i in sorted_idx}

# ====== MAIN EXECUTION ======
if __name__ == "__main__":
    # Run training
    history_list, metrics, class_indices, X, y = run_training()
    
    # Visualize results
    plot_results(history_list, metrics, class_indices, X, y)
    
    # Example prediction
    predictor = DenseNetPredictor('densenet_fold_1.keras', class_indices)  # Changed to densenet
    test_image = os.path.join(Config.BASE_DIR, 'NO Dr/005b95c28852.png')
    
    if os.path.exists(test_image):
        print("\nMaking prediction on test image...")
        predictions = predictor.predict_image(test_image)
        print("\nPrediction Probabilities:")
        for cls, prob in predictions.items():
            print(f"{cls}: {prob*100:.2f}%")
    else:
        print(f"\nTest image not found at: {test_image}")
        print("Please provide a valid image path for prediction.")
# Out:
# Found 400 images belonging to 5 classes.
#
# === DATA VALIDATION ===
# Class distribution in training: Counter({0: 80, 1: 80, 2: 80, 3: 80, 4: 80})
# Found 100 images belonging to 5 classes.
# Class distribution in validation: Counter({0: 20, 1: 20, 2: 20, 3: 20, 4: 20})
# Number of overlapping files: 0
#
# 🔵 Fold 1
# I0000 00:00:1747320664.543809      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1
- learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3102 - auc: 0.6514 - loss: 4.9773 - precision: 0.3316 - recall: 0.2146 - val_accuracy: 0.4750 - val_auc: 0.8099 - val_loss: 4.2395 - val_precision: 0.6818 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2987 - auc: 0.6449 - loss: 4.9487 - precision: 0.3410 - recall: 0.2458 - val_accuracy: 0.5250 - val_auc: 0.8157 - val_loss: 4.1728 - val_precision: 0.6667 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3022 - auc: 0.6197 - loss: 5.1147 - precision: 0.3133 - recall: 0.2308 - val_accuracy: 0.5250 - val_auc: 0.8194 - val_loss: 4.1117 - val_precision: 0.6429 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3495 - auc: 0.6442 - loss: 4.8942 - precision: 0.3497 - recall: 0.2353 - val_accuracy: 0.5625 - val_auc: 0.8239 - val_loss: 4.0514 - val_precision: 0.6207 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.3607 - auc: 0.6759 - loss: 4.7447 - precision: 0.4016 - recall: 0.2877 - val_accuracy: 0.5750 - val_auc: 0.8322 - val_loss: 3.9837 - val_precision: 0.6667 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3628 - auc: 0.6580 - loss: 4.7557 - precision: 0.3695 - recall: 0.2658 - val_accuracy: 0.5875 - val_auc: 0.8392 - val_loss: 3.9225 - val_precision: 0.6923 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3397 - auc: 0.6591 - loss: 4.6446 - precision: 0.3744 - recall: 0.2635 - val_accuracy: 0.5750 - val_auc: 0.8486 - val_loss: 3.8592 - val_precision: 0.7600 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.3223 - auc: 0.6553 - loss: 4.7229 - precision: 0.3523 - recall: 0.2551 - val_accuracy: 0.5875 - val_auc: 0.8503 - val_loss: 3.8183 - val_precision: 0.7692 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.3601 - auc: 0.6638 - loss: 4.6172 - precision: 0.3693 - recall: 0.2600 - val_accuracy: 0.6000 - val_auc: 0.8491 - val_loss: 3.7809 - val_precision: 0.7407 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3005 - auc: 0.6280 - loss: 4.7319 - precision: 0.3344 - recall: 0.2448 - val_accuracy: 0.5875 - val_auc: 0.8530 - val_loss: 3.7362 - val_precision: 0.7500 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.3476 - auc: 0.6401 - loss: 4.6187 - precision: 0.3898 - recall: 0.2751 - val_accuracy: 0.5500 - val_auc: 0.8574 - val_loss: 3.6914 - val_precision: 0.7931 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.4165 - auc: 0.7069 - loss: 4.3378 - precision: 0.4504 - recall: 0.3217 - val_accuracy: 0.5875 - val_auc: 0.8628 - val_loss: 3.6430 - val_precision: 0.7742 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.
- learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2261 - auc: 0.5421 - loss: 5.8085 - precision: 0.2184 - recall: 0.1545 - val_accuracy: 0.4750 - val_auc: 0.7069 - val_loss: 4.7256 - val_precision: 0.5000 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2362 - auc: 0.5576 - loss: 5.6617 - precision: 0.2432 - recall: 0.1748 - val_accuracy: 0.5125 - val_auc: 0.7227 - val_loss: 4.6375 - val_precision: 0.5714 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3123 - auc: 0.6017 - loss: 5.4025 - precision: 0.2992 - recall: 0.2245 - val_accuracy: 0.5250 - val_auc: 0.7292 - val_loss: 4.5632 - val_precision: 0.5882 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3168 - auc: 0.6150 - loss: 5.2447 - precision: 0.3309 - recall: 0.2290 - val_accuracy: 0.5375 - val_auc: 0.7315 - val_loss: 4.4953 - val_precision: 0.6316 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.3179 - auc: 0.6287 - loss: 5.2020 - precision: 0.3071 - recall: 0.2104 - val_accuracy: 0.5125 - val_auc: 0.7392 - val_loss: 4.4213 - val_precision: 0.6957 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2866 - auc: 0.5924 - loss: 5.2310 - precision: 0.2779 - recall: 0.1863 - val_accuracy: 0.5375 - val_auc: 0.7563 - val_loss: 4.3382 - val_precision: 0.7200 - val_recall: 0.2250 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2970 - auc: 0.6208 - loss: 5.1042 - precision: 0.3721 - recall: 0.2588 - val_accuracy: 0.5375 - val_auc: 0.7720 - val_loss: 4.2625 - val_precision: 0.7308 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.3039 - auc: 0.6409 - loss: 4.9118 - precision: 0.3290 - recall: 0.2214 - val_accuracy: 0.5375 - val_auc: 0.7763 - val_loss: 4.2076 - val_precision: 0.7407 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.2854 - auc: 0.6164 - loss: 5.0224 - precision: 0.3353 - recall: 0.2216 - val_accuracy: 0.5500 - val_auc: 0.7763 - val_loss: 4.1588 - val_precision: 0.7407 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 2 Results:
# Accuracy: 53.75%
# AUC: 0.7640
#
# 🔵 Fold 3
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 45s 370ms/step - accuracy: 0.2369 - auc: 0.4997 - loss: 6.8667 - precision: 0.2170 - recall: 0.1566 - val_accuracy: 0.1250 - val_auc: 0.4103 - val_loss: 6.0761 - val_precision: 0.0625 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2335 - auc: 0.5215 - loss: 6.5408 - precision: 0.2113 - recall: 0.1490 - val_accuracy: 0.1500 - val_auc: 0.4461 - val_loss: 5.7776 - val_precision: 0.2500 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.1955 - auc: 0.4719 - loss: 6.7219 - precision: 0.1667 - recall: 0.1096 - val_accuracy: 0.1375 - val_auc: 0.4949 - val_loss: 5.5601 - val_precision: 1.0000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.1692 - auc: 0.4906 - loss: 6.5370 - precision: 0.1675 - recall: 0.1154 - val_accuracy: 0.2000 - val_auc: 0.5633 - val_loss: 5.3809 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.2497 - auc: 0.5391 - loss: 6.2383 - precision: 0.2544 - recall: 0.1742 - val_accuracy: 0.2750 - val_auc: 0.6216 - val_loss: 5.2317 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3138 - auc: 0.5915 - loss: 5.8122 - precision: 0.3357 - recall: 0.2309 - val_accuracy: 0.3375 - val_auc: 0.6757 - val_loss: 5.0953 - val_precision: 1.0000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.2243 - auc: 0.5090 - loss: 6.1975 - precision: 0.2179 - recall: 0.1482 - val_accuracy: 0.3750 - val_auc: 0.7049 - val_loss: 4.9884 - val_precision: 1.0000 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.1997 - auc: 0.5421 - loss: 5.9495 - precision: 0.2415 - recall: 0.1538 - val_accuracy: 0.4375 - val_auc: 0.7426 - val_loss: 4.8671 - val_precision: 1.0000 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.3021 - auc: 0.5782 - loss: 5.6850 - precision: 0.2999 - recall: 0.1883 - val_accuracy: 0.4625 - val_auc: 0.7734 - val_loss: 4.7569 - val_precision: 1.0000 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2596 - auc: 0.5571 - loss: 5.8039 - precision: 0.2585 - recall: 0.1734 - val_accuracy: 0.4875 - val_auc: 0.8002 - val_loss: 4.6637 - val_precision: 1.0000 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.2702 - auc: 0.5717 - loss: 5.5820 - precision: 0.2604 - recall: 0.1714 - val_accuracy: 0.5500 - val_auc: 0.8195 - val_loss: 4.5720 - val_precision: 1.0000 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.2643 - auc: 0.5805 - loss: 5.5551 - precision: 0.2682 - recall: 0.1958 - val_accuracy: 0.5625 - val_auc: 0.8296 - val_loss: 4.4908 - val_precision: 1.0000 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.2851 - auc: 0.5756 - loss: 5.4407 - precision: 0.2801 - recall: 0.1896 - val_accuracy: 0.5750 - val_auc: 0.8417 - val_loss: 4.4071 - val_precision: 1.0000 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2656 - auc: 0.6024 - loss: 5.3014 - precision: 0.3280 - recall: 0.2119 - val_accuracy: 0.6000 - val_auc: 0.8547 - val_loss: 4.3241 - val_precision: 1.0000 - val_recall: 0.1125 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3359 - auc: 0.5906 - loss: 5.3213 - precision: 0.3083 - recall: 0.2070 - val_accuracy: 0.6125 - val_auc: 0.8582 - val_loss: 4.2569 - val_precision: 1.0000 - val_recall: 0.1375 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.2822 - auc: 0.6100 - loss: 5.2419 - precision: 0.3282 - recall: 0.2318 - val_accuracy: 0.6000 - val_auc: 0.8658 - val_loss: 4.1865 - val_precision: 1.0000 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3195 - auc: 0.6255 - loss: 5.0882 - precision: 0.3472 - recall: 0.2483 - val_accuracy: 0.6250 - val_auc: 0.8781 - val_loss: 4.1016 - val_precision: 1.0000 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2955 - auc: 0.5992 - loss: 5.1773 - precision: 0.3115 - recall: 0.2220 - val_accuracy: 0.6250 - val_auc: 0.8831 - val_loss: 4.0298 - val_precision: 1.0000 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2722 - auc: 0.6129 - loss: 5.0341 - precision: 0.2977 - recall: 0.2074 - val_accuracy: 0.6000 - val_auc: 0.8877 - val_loss: 3.9660 - val_precision: 1.0000 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2788 - auc: 0.5707 - loss: 5.1127 - precision: 0.2891 - recall: 0.2039 - val_accuracy: 0.6250 - val_auc: 0.8957 - val_loss: 3.8999 - val_precision: 1.0000 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3557 - auc: 0.6139 - loss: 4.9360 - precision: 0.3317 - recall: 0.2425 - val_accuracy: 0.6375 - val_auc: 0.9010 - val_loss: 3.8404 - val_precision: 0.9643 - val_recall: 0.3375 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3183 - auc: 0.6273 - loss: 4.8108 - precision: 0.3342 - recall: 0.2206 - val_accuracy: 0.6375 - val_auc: 0.9032 - val_loss: 3.7826 - val_precision: 0.9667 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.3099 - auc: 0.5988 - loss: 4.9220 - precision: 0.3174 - recall: 0.2099 - val_accuracy: 0.6375 - val_auc: 0.9080 - val_loss: 3.7299 - val_precision: 0.9667 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.2783 - auc: 0.6091 - loss: 4.8637 - precision: 0.3066 - recall: 0.2101 - val_accuracy: 0.6375 - val_auc: 0.9115 - val_loss: 3.6764 - val_precision: 0.9677 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3401 - auc: 0.6700 - loss: 4.5855 - precision: 0.3854 - recall: 0.2722 - val_accuracy: 0.6250 - val_auc: 0.9136 - val_loss: 3.6246 - val_precision: 0.9677 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2913 - auc: 0.6139 - loss: 4.7952 - precision: 0.3208 - recall: 0.2246 - val_accuracy: 0.6375 - val_auc: 0.9169 - val_loss: 3.5783 - val_precision: 0.9677 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3095 - auc: 0.5923 - loss: 4.8702 - precision: 0.3130 - recall: 0.2263 - val_accuracy: 0.6375 - val_auc: 0.9198 - val_loss: 3.5391 - val_precision: 0.9677 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3216 - auc: 0.6579 - loss: 4.4974 - precision: 0.3788 - recall: 0.2552 - val_accuracy: 0.6250 - val_auc: 0.9181 - val_loss: 3.4992 - val_precision: 0.9429 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.2607 - auc: 0.5941 - loss: 4.7663 - precision: 0.3187 - recall: 0.2165 - val_accuracy: 0.6375 - val_auc: 0.9194 - val_loss: 3.4643 - val_precision: 0.9444 - val_recall: 0.4250 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3674 - auc: 0.6846 - loss: 4.3456 - precision: 0.4187 - recall: 0.2836 - val_accuracy: 0.6375 - val_auc: 0.9205 - val_loss: 3.4252 - val_precision: 0.9459 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2998 - auc: 0.6424 - loss: 4.4665 - precision: 0.2945 - recall: 0.1947 - val_accuracy: 0.6500 - val_auc: 0.9242 - val_loss: 3.3843 - val_precision: 0.8974 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3697 - auc: 0.6835 - loss: 4.3305 - precision: 0.4052 - recall: 0.2762 - val_accuracy: 0.6750 - val_auc: 0.9257 - val_loss: 3.3420 - val_precision: 0.9211 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3790 - auc: 0.6554 - loss: 4.3828 - precision: 0.4467 - recall: 0.2901 - val_accuracy: 0.6500 - val_auc: 0.9265 - val_loss: 3.3076 - val_precision: 0.9211 - val_recall: 0.4375 - learning_rate: 3.0000e-05
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0
- val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.4044 - auc: 0.7108 - loss: 3.8791 - precision: 0.4669 - recall: 0.3445 - val_accuracy: 0.6625 - val_auc: 0.9355 - val_loss: 2.9358 - val_precision: 0.8810 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5118 - auc: 0.7539 - loss: 3.6810 - precision: 0.5689 - recall: 0.4077 - val_accuracy: 0.6875 - val_auc: 0.9344 - val_loss: 2.9202 - val_precision: 0.8810 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4018 - auc: 0.7091 - loss: 3.8614 - precision: 0.4120 - recall: 0.3016 - val_accuracy: 0.6500 - val_auc: 0.9346 - val_loss: 2.9061 - val_precision: 0.8810 - val_recall: 0.4625 - learning_rate: 3.0000e-05
# ✅ Fold 3 Results:
# Accuracy: 66.25%
# AUC: 0.9346
#
# 🔵 Fold 4
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 46s 404ms/step - accuracy: 0.1912 - auc: 0.5264 - loss: 6.5927 - precision: 0.2010 - recall: 0.1356 - val_accuracy: 0.1875 - val_auc: 0.4766 - val_loss: 6.0245 - val_precision: 0.2391 - val_recall: 0.1375 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.1868 - auc: 0.4857 - loss: 6.8287 - precision: 0.1658 - recall: 0.1200 - val_accuracy: 0.1750 - val_auc: 0.4927 - val_loss: 5.7479 - val_precision: 0.0588 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.2681 - auc: 0.5465 - loss: 6.3864 - precision: 0.3002 - recall: 0.2155 - val_accuracy: 0.2000 - val_auc: 0.5195 - val_loss: 5.5857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3053 - auc: 0.5626 - loss: 6.2464 - precision: 0.3177 - recall: 0.2290 - val_accuracy: 0.2375 - val_auc: 0.5391 - val_loss: 5.4764 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2114 - auc: 0.5271 - loss: 6.2698 - precision: 0.2027 - recall: 0.1430 - val_accuracy: 0.2750 - val_auc: 0.5599 - val_loss: 5.3672 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2199 - auc: 0.5376 - loss: 6.0912 - precision: 0.2172 - recall: 0.1511 - val_accuracy: 0.3000 - val_auc: 0.5704 - val_loss: 5.2898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3019 - auc: 0.5927 - loss: 5.8496 - precision: 0.3112 - recall: 0.2292 - val_accuracy: 0.3250 - val_auc: 0.5818 - val_loss: 5.2129 - val_precision: 0.1000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2481 - auc: 0.5587 - loss: 5.8770 - precision: 0.2371 - recall: 0.1723 - val_accuracy: 0.3625 - val_auc: 0.5993 - val_loss: 5.1122 - val_precision: 0.2000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2570 - auc: 0.6000 - loss: 5.6345 - precision: 0.2808 - recall: 0.1952 - val_accuracy: 0.3750 - val_auc: 0.6165 - val_loss: 5.0148 - val_precision: 0.2500 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2095 - auc: 0.5657 - loss: 5.7397 - precision: 0.2173 - recall: 0.1622 - val_accuracy: 0.4000 - val_auc: 0.6313 - val_loss: 4.9200 - val_precision: 0.2857 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3029 - auc: 0.6082 - loss: 5.4864 - precision: 0.3418 - recall: 0.2306 - val_accuracy: 0.4000 - val_auc: 0.6494 - val_loss: 4.8177 - val_precision: 0.4000 - val_recall: 0.0750 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3164 - auc: 0.6014 - loss: 5.5101 - precision: 0.3391 - recall: 0.2465 - val_accuracy: 0.4125 - val_auc: 0.6595 - val_loss: 4.7478 - val_precision: 0.4545 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2443 - auc: 0.5522 - loss: 5.5907 - precision: 0.2543 - recall: 0.1605 - val_accuracy: 0.4500 - val_auc: 0.6676 - val_loss: 4.6768 - val_precision: 0.4800 - val_recall: 0.1500 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.2743 - auc: 0.5968 - loss: 5.3385 - precision: 0.2755 - recall: 0.1996 - val_accuracy: 0.4375 - val_auc: 0.6696 - val_loss: 4.6256 - val_precision: 0.4643 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3217 - auc: 0.6297 - loss: 5.2288 - precision: 0.3135 - recall: 0.2259 - val_accuracy: 0.4500 - val_auc: 0.6796 - val_loss: 4.5567 - val_precision: 0.5172 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2955 - auc: 0.5912 - loss: 5.2665 - precision: 0.3634 - recall: 0.2562 - val_accuracy: 0.4500 - val_auc: 0.6874 - val_loss: 4.4974 - val_precision: 0.5152 - val_recall: 0.2125 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2914 - auc: 0.6267 - loss: 5.0846 - precision: 0.3064 - recall: 0.2266 - val_accuracy: 0.4500 - val_auc: 0.6906 - val_loss: 4.4568 - val_precision: 0.5610 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3330 - auc: 0.6456 - loss: 4.9378 - precision: 0.3833 - recall: 0.2724 - val_accuracy: 0.4500 - val_auc: 0.6931 - val_loss: 4.4087 - val_precision: 0.5111 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2944 - auc: 0.6422 - loss: 4.8439 - precision: 0.2800 - recall: 0.1897 - val_accuracy: 0.4500 - val_auc: 0.7089 - val_loss: 4.3292 - val_precision: 0.5682 - val_recall: 0.3125 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.4015 - auc: 0.6919 - loss: 4.6892 - precision: 0.4582 - recall: 0.3230 - val_accuracy: 0.4500 - val_auc: 0.7141 - val_loss: 4.2793 - val_precision: 0.6042 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3488 - auc: 0.6361 - loss: 4.8575 - precision: 0.4323 - recall: 0.2872 - val_accuracy: 0.4500 - val_auc: 0.7180 - val_loss: 4.2293 - val_precision: 0.5800 - val_recall: 0.3625 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.3554 - auc: 0.6792 - loss: 4.5887 - precision: 0.4092 - recall: 0.2734 - val_accuracy: 0.4625 - val_auc: 0.7253 - val_loss: 4.1687 - val_precision: 0.6122 - val_recall: 0.3750 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.3742 - auc: 0.6671 - loss: 4.7354 - precision: 0.3968 - recall: 0.2948 - val_accuracy: 0.4625 - val_auc: 0.7372 - val_loss: 4.1073 - val_precision: 0.5962 - val_recall: 0.3875 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.4091 - auc: 0.6763 - loss: 4.6071 - precision: 0.4696 - recall: 0.3322 - val_accuracy: 0.4625 - val_auc: 0.7424 - val_loss: 4.0622 - val_precision: 0.5962 - val_recall: 0.3875 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.3607 - auc: 0.6679 - loss: 4.5722 - precision: 0.3997 - recall: 0.2716 - val_accuracy: 0.4625 - val_auc: 0.7507 - val_loss: 4.0094 - val_precision: 0.6078 - val_recall: 0.3875 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.3083 - auc: 0.6372 - loss: 4.6874 - precision: 0.3639 - recall: 0.2674 - val_accuracy: 0.4875 - val_auc: 0.7539 - val_loss: 3.9679 - val_precision: 0.6275 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.4502 - auc: 0.7283 - loss: 4.2508 - precision: 0.4714 - recall: 0.3503 - val_accuracy: 0.4875 - val_auc: 0.7559 - val_loss: 3.9379 - val_precision: 0.5926 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.3898 - auc: 0.6597 - loss: 4.4856 - precision: 0.4413 - recall: 0.2722 - val_accuracy: 0.4875 - val_auc: 0.7565 - val_loss: 3.9196 - val_precision: 0.5517 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3544 - auc: 0.6651 - loss: 4.3908 - precision: 0.3923 - recall: 0.2530 - val_accuracy: 0.4875 - val_auc: 0.7607 - val_loss: 3.8770 - val_precision: 0.5818 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2832 - auc: 0.6132 - loss: 4.6524 - precision: 0.3158 - recall: 0.2328 - val_accuracy: 0.4875 - val_auc: 0.7682 - val_loss: 3.8348 - val_precision: 0.5714 - val_recall: 0.4000 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.3814 - auc: 0.6947 - loss: 4.3069 - precision: 0.4258 - recall: 0.3083 - val_accuracy: 0.4875 - val_auc: 0.7670 - val_loss: 3.8082 - val_precision: 0.5789 - val_recall: 0.4125 - learning_rate: 3.0000e-05
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ✅ Fold 4 Results:
# Accuracy: 48.75%
# AUC: 0.7616
#
# 🔵 Fold 5
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 45s 371ms/step - accuracy: 0.2366 - auc: 0.5025 - loss: 6.7969 - precision: 0.2132 - recall: 0.1616 - val_accuracy: 0.1125 - val_auc: 0.4272 - val_loss: 5.9840 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2326 - auc: 0.5038 - loss: 6.8017 - precision: 0.2658 - recall: 0.2008 - val_accuracy: 0.1125 - val_auc: 0.4449 - val_loss: 5.7049 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.1507 - auc: 0.5111 - loss: 6.4216 - precision: 0.1505 - recall: 0.1046 - val_accuracy: 0.1625 - val_auc: 0.4810 - val_loss: 5.5312 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2042 - auc: 0.5209 - loss: 6.3988 - precision: 0.2357 - recall: 0.1638 - val_accuracy: 0.2500 - val_auc: 0.5284 - val_loss: 5.4096 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.1454 - auc: 0.4923 - loss: 6.3018 - precision: 0.1278 - recall: 0.0834 - val_accuracy: 0.2625 - val_auc: 0.5713 - val_loss: 5.2930 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2073 - auc: 0.5167 - loss: 6.3289 - precision: 0.2117 - recall: 0.1456 - val_accuracy: 0.2500 - val_auc: 0.6019 - val_loss: 5.1867 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 3.0000e-05
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2805 - auc: 0.5627 - loss: 5.9248 - precision: 0.2759 - recall: 0.1759 - val_accuracy: 0.2625 - val_auc: 0.6309 - val_loss: 5.0840 - val_precision: 1.0000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2202 - auc: 0.5613 - loss: 5.8715 - precision: 0.2459 - recall: 0.1686 - val_accuracy: 0.3125 - val_auc: 0.6556 - val_loss: 4.9888 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.1847 - auc: 0.5281 - loss: 5.9411 - precision: 0.1978 - recall: 0.1459 - val_accuracy: 0.3125 - val_auc: 0.6742 - val_loss: 4.9046 - val_precision: 0.5000 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.2805 - auc: 0.5470 - loss: 5.7962 - precision: 0.2412 - recall: 0.1489 - val_accuracy: 0.3500 - val_auc: 0.6952 - val_loss: 4.8089 - val_precision: 0.3333 - val_recall: 0.0125 - learning_rate: 3.0000e-05
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2371 - auc: 0.5657 - loss: 5.5885 - precision: 0.2613 - recall: 0.1694 - val_accuracy: 0.3500 - val_auc: 0.7013 - val_loss: 4.7415 - val_precision: 0.5000 - val_recall: 0.0250 - learning_rate: 3.0000e-05
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2895 - auc: 0.5715 - loss: 5.6472 - precision: 0.2927 - recall: 0.2024 - val_accuracy: 0.3875 - val_auc: 0.7177 - val_loss: 4.6549 - val_precision: 0.4286 - val_recall: 0.0375 - learning_rate: 3.0000e-05
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.2943 - auc: 0.6342 - loss: 5.2173 - precision: 0.3285 - recall: 0.2257 - val_accuracy: 0.4250 - val_auc: 0.7327 - val_loss: 4.5713 - val_precision: 0.4444 - val_recall: 0.0500 - learning_rate: 3.0000e-05
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.2923 - auc: 0.6066 - loss: 5.2679 - precision: 0.3095 - recall: 0.2249 - val_accuracy: 0.4125 - val_auc: 0.7438 - val_loss: 4.4960 - val_precision: 0.5000 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.2507 - auc: 0.5874 - loss: 5.2994 - precision: 0.2758 - recall: 0.1894 - val_accuracy: 0.4625 - val_auc: 0.7535 - val_loss: 4.4289 - val_precision: 0.4545 - val_recall: 0.0625 - learning_rate: 3.0000e-05
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.3036 - auc: 0.6057 - loss: 5.1744 - precision: 0.3458 - recall: 0.2371 - val_accuracy: 0.4625 - val_auc: 0.7563 - val_loss: 4.3646 - val_precision: 0.5385 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2952 - auc: 0.6318 - loss: 4.9775 - precision: 0.3448 - recall: 0.2143 - val_accuracy: 0.4750 - val_auc: 0.7674 - val_loss: 4.2947 - val_precision: 0.5385 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.2812 - auc: 0.6025 - loss: 5.1306 - precision: 0.2693 - recall: 0.1809 - val_accuracy: 0.4625 - val_auc: 0.7758 - val_loss: 4.2326 - val_precision: 0.5385 - val_recall: 0.0875 - learning_rate: 3.0000e-05
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3356 - auc: 0.6179 - loss: 5.0573 - precision: 0.3344 - recall: 0.2284 - val_accuracy: 0.4750 - val_auc: 0.7823 - val_loss: 4.1709 - val_precision: 0.5714 - val_recall: 0.1000 - learning_rate: 3.0000e-05
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3828 - auc: 0.6645 - loss: 4.7384 - precision: 0.4113 - recall: 0.3001 - val_accuracy: 0.4875 - val_auc: 0.7904 - val_loss: 4.1101 - val_precision: 0.5882 - val_recall: 0.1250 - learning_rate: 3.0000e-05
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.3201 - auc: 0.6424 - loss: 4.8273 - precision: 0.3632 - recall: 0.2586 - val_accuracy: 0.5125 - val_auc: 0.7972 - val_loss: 4.0516 - val_precision: 0.7222 - val_recall: 0.1625 - learning_rate: 3.0000e-05
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3331 - auc: 0.6620 - loss: 4.6829 - precision: 0.3729 - recall: 0.2531 - val_accuracy: 0.5000 - val_auc: 0.8080 - val_loss: 3.9894 - val_precision: 0.7500 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3332 - auc: 0.6245 - loss: 4.8008 - precision: 0.3617 - recall: 0.2482 - val_accuracy: 0.5000 - val_auc: 0.8132 - val_loss: 3.9346 - val_precision: 0.7500 - val_recall: 0.1875 - learning_rate: 3.0000e-05
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3768 - auc: 0.6596 - loss: 4.6491 - precision: 0.3992 - recall: 0.3054 - val_accuracy: 0.5000 - val_auc: 0.8182 - val_loss: 3.8801 - val_precision: 0.7619 - val_recall: 0.2000 - learning_rate: 3.0000e-05
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3489 - auc: 0.6929 - loss: 4.4712 - precision: 0.4053 - recall: 0.2917 - val_accuracy: 0.5125 - val_auc: 0.8196 - val_loss: 3.8337 - val_precision: 0.7917 - val_recall: 0.2375 - learning_rate: 3.0000e-05
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3899 - auc: 0.7145 - loss: 4.3102 - precision: 0.4227 - recall: 0.3074 - val_accuracy: 0.5000 - val_auc: 0.8227 - val_loss: 3.7876 - val_precision: 0.8077 - val_recall: 0.2625 - learning_rate: 3.0000e-05
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.4310 - auc: 0.6998 - loss: 4.3370 - precision: 0.4956 - recall: 0.3228 - val_accuracy: 0.5000 - val_auc: 0.8241 - val_loss: 3.7491 - val_precision: 0.7692 - val_recall: 0.2500 - learning_rate: 3.0000e-05
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3425 - auc: 0.6911 - loss: 4.3355 - precision: 0.3866 - recall: 0.2699 - val_accuracy: 0.5000 - val_auc: 0.8287 - val_loss: 3.7035 - val_precision: 0.7857 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3785 - auc: 0.7081 - loss: 4.2400 - precision: 0.4049 - recall: 0.3169 - val_accuracy: 0.4750 - val_auc: 0.8342 - val_loss: 3.6617 - val_precision: 0.8214 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.3755 - auc: 0.6982 - loss: 4.2377 - precision: 0.4584 - recall: 0.2980 - val_accuracy: 0.4875 - val_auc: 0.8365 - val_loss: 3.6259 - val_precision: 0.8148 - val_recall: 0.2750 - learning_rate: 3.0000e-05
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3957 - auc: 0.6702 - loss: 4.3338 - precision: 0.3785 - recall: 0.2558 - val_accuracy: 0.5000 - val_auc: 0.8392 - val_loss: 3.5931 - val_precision: 0.8000 - val_recall: 0.3000 - learning_rate: 3.0000e-05
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.3509 - auc: 0.6778 - loss: 4.2636 - precision: 0.4595 - recall: 0.3143 - val_accuracy: 0.5000 - val_auc: 0.8420 - val_loss: 3.5578 - val_precision: 0.7931 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.3793 - auc: 0.6983 - loss: 4.2008 - precision: 0.4419 - recall: 0.3218 - val_accuracy: 0.4750 - val_auc: 0.8418 - val_loss: 3.5284 - val_precision: 0.7931 - val_recall: 0.2875 - learning_rate: 3.0000e-05
# ✅ Fold 5 Results:
# Accuracy: 50.00%
# AUC: 0.8387
#
# === CROSS-VALIDATION RESULTS ===
# Accuracy: 0.5575 ± 0.0655
# Precision: 0.5278 ± 0.1388
# Recall: 0.5575 ± 0.0655
# F1: 0.5064 ± 0.0959
# Auc: 0.8385 ± 0.0688
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step
# Making prediction on test image...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# Prediction Probabilities:
# NO Dr: 73.76%
# Mild: 16.88%
# Severe Dr: 4.65%
# Moderate: 2.51%
# Proliferative_DR: 2.21%
